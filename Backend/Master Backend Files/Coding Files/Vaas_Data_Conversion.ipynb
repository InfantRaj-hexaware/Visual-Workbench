# %%
TRAIN_DATA=[("Show me Rate Chg % for all portfolio",{"entities":[(9,19,"Measure"),(27,36,"Categorical Dimension")]}),
("Show me Retention % for all client ",{"entities":[(9,20,"Measure"),(28,34,"Categorical Dimension")]}),
("Show me Bound Premium for all risk group ",{"entities":[(8,21,"Measure"),(30,40,"Categorical Dimension")]}),
("Show me Overheads for all broker ",{"entities":[(8,17,"Measure"),(26,32,"Categorical Dimension")]}),
("Show me EBITDA for all lloyd's broker ",{"entities":[(8,14,"Measure"),(23,37,"Categorical Dimension")]}),
("Show me Revenue per day for all event ",{"entities":[(8,23,"Measure"),(32,37,"Categorical Dimension")]}),
("Show me Net Profit Margin for all accounting classes ",{"entities":[(8,25,"Measure"),(34,52,"Categorical Dimension")]}),
("Show me GM for all Claim severity ",{"entities":[(8,10,"Measure"),(19,33,"Categorical Dimension")]}),
("Show me Gross Margin for all policy holder ",{"entities":[(8,20,"Measure"),(29,42,"Categorical Dimension")]}),
("Show me Expense for all policy type ",{"entities":[(8,15,"Measure"),(24,35,"Categorical Dimension")]}),
("Show me Revenue for all policy ",{"entities":[(8,15,"Measure"),(24,30,"Categorical Dimension")]}),
("Show me Growth% for all Product Name ",{"entities":[(8,16,"Measure"),(24,36,"Categorical Dimension")]}),
("Show me attrition rate for all Product class ",{"entities":[(8,22,"Measure"),(31,44,"Categorical Dimension")]}),
("Show me layover for all Product type ",{"entities":[(8,15,"Measure"),(24,36,"Categorical Dimension")]}),
("Show me retention rate for all Product category ",{"entities":[(8,22,"Measure"),(31,47,"Categorical Dimension")]}),
("Show me training period for all Revenue Type ",{"entities":[(8,23,"Measure"),(32,44,"Categorical Dimension")]}),
("Show me ctc for all managing agent ",{"entities":[(8,11,"Measure"),(20,34,"Categorical Dimension")]}),
("Show me time to fill for all agent ",{"entities":[(8,20,"Measure"),(29,34,"Categorical Dimension")]}),
("Show me number of hires for all Claim status ",{"entities":[(7,23,"Measure"),(32,44,"Categorical Dimension")]}),
("Show me number of recruitments for all Claim type ",{"entities":[(8,30,"Measure"),(39,49,"Categorical Dimension")]}),
("Show me recruitment cost for all Age group ",{"entities":[(8,24,"Measure"),(33,42,"Categorical Dimension")]}),
("Show me training days for all Group ",{"entities":[(8,21,"Measure"),(30,35,"Categorical Dimension")]}),
("Show me training cost for all cohort ",{"entities":[(8,21,"Measure"),(30,36,"Categorical Dimension")]}),
("Show me variable pay for all Order status ",{"entities":[(8,20,"Measure"),(29,41,"Categorical Dimension")]}),
("Show me fixed pay for all Status ",{"entities":[(8,17,"Measure"),(26,32,"Categorical Dimension")]}),
("Show me bonus for all Size ",{"entities":[(8,13,"Measure"),(22,26,"Categorical Dimension")]}),
("Show me working hours for all Type ",{"entities":[(8,21,"Measure"),(30,34,"Categorical Dimension")]}),
("Show me experience for all Quality ",{"entities":[(8,18,"Measure"),(27,34,"Categorical Dimension")]}),
("Show me Sick leaves for all Grade ",{"entities":[(8,19,"Measure"),(28,33,"Categorical Dimension")]}),
("Show me earned leaves for all Class ",{"entities":[(8,21,"Measure"),(30,35,"Categorical Dimension")]}),
("Show me salary for all Mode ",{"entities":[(8,14,"Measure"),(23,27,"Categorical Dimension")]}),
("Show me number of employees for all Method ",{"entities":[(8,27,"Measure"),(36,42,"Categorical Dimension")]}),
("Show me dividend rate for all Channel ",{"entities":[(8,21,"Measure"),(30,37,"Categorical Dimension")]}),
("Show me dividend for all Item ",{"entities":[(8,16,"Measure"),(25,29,"Categorical Dimension")]}),
("Show me D/E Ratio for all Department ",{"entities":[(8,17,"Measure"),(26,36,"Categorical Dimension")]}),
("Show me CAPEX for all order type ",{"entities":[(8,13,"Measure"),(22,32,"Categorical Dimension")]}),
("Show me OPEX for all Section ",{"entities":[(8,12,"Measure"),(21,28,"Categorical Dimension")]}),
("Show me Turnover for all Division ",{"entities":[(8,16,"Measure"),(25,33,"Categorical Dimension")]}),
("Show me Working Capital for all Brand ",{"entities":[(7,23,"Measure"),(32,37,"Categorical Dimension")]}),
("Show me Burn rate for all Category ",{"entities":[(8,17,"Measure"),(26,34,"Categorical Dimension")]}),
("Show me OCF for all Lines ",{"entities":[(7,11,"Measure"),(20,25,"Categorical Dimension")]}),
("Show me Operating Cash Flow for all Store ",{"entities":[(8,27,"Measure"),(36,41,"Categorical Dimension")]}),
("Show me EBIT% for all store name ",{"entities":[(8,13,"Measure"),(22,32,"Categorical Dimension")]}),
("Show me EBITDA% for all Zones ",{"entities":[(8,15,"Measure"),(24,29,"Categorical Dimension")]}),
("Show me Operating Profit% for all Block ",{"entities":[(8,25,"Measure"),(34,39,"Categorical Dimension")]}),
("Show me GM% for all Region ",{"entities":[(8,11,"Measure"),(20,26,"Categorical Dimension")]}),
("Show me Gross Margin% for all State ",{"entities":[(8,21,"Measure"),(30,35,"Categorical Dimension")]}),
("Show me Profit Margin% for all City ",{"entities":[(8,22,"Measure"),(31,35,"Categorical Dimension")]}),
("Show me Profit% for all Country ",{"entities":[(8,15,"Measure"),(23,31,"Categorical Dimension")]}),
("Show me Profit for all Location ",{"entities":[(8,14,"Measure"),(23,31,"Categorical Dimension")]}),
("Show me Loss% for all length of service slabs ",{"entities":[(7,13,"Measure"),(22,45,"Categorical Dimension")]}),
("Show me Loss for all employee performance ",{"entities":[(8,12,"Measure"),(21,41,"Categorical Dimension")]}),
("Show me Tax for all source ",{"entities":[(8,11,"Measure"),(20,26,"Categorical Dimension")]}),
("Show me Interest rate for all business unit ",{"entities":[(8,21,"Measure"),(30,43,"Categorical Dimension")]}),
("Show me Exceptionals for all zone ",{"entities":[(8,20,"Measure"),(29,33,"Categorical Dimension")]}),
("Show me Monitoring costs for all gender ",{"entities":[(8,24,"Measure"),(33,39,"Categorical Dimension")]}),
("Show me Direct Cost for all years of service ",{"entities":[(8,19,"Measure"),(28,44,"Categorical Dimension")]}),
("Show me Depreciation for all position ",{"entities":[(7,20,"Measure"),(29,37,"Categorical Dimension")]}),
("Show me Other income for all department ",{"entities":[(8,20,"Measure"),(29,39,"Categorical Dimension")]}),
("Show me EBIT for all hierarchy ",{"entities":[(8,12,"Measure"),(21,30,"Categorical Dimension")]}),
("Show me Operating Income for all location ",{"entities":[(8,24,"Measure"),(33,41,"Categorical Dimension")]}),
("Show me Operating Profit for all division ",{"entities":[(8,24,"Measure"),(33,41,"Categorical Dimension")]}),
("Show me Cost of Sales for all service group ",{"entities":[(8,21,"Measure"),(30,43,"Categorical Dimension")]}),
("Show me vacation days for all age group ",{"entities":[(7,21,"Measure"),(30,39,"Categorical Dimension")]}),
("Show me leavers for all levels ",{"entities":[(8,15,"Measure"),(24,30,"Categorical Dimension")]}),
("Show me work tenure for all grade ",{"entities":[(8,19,"Measure"),(28,33,"Categorical Dimension")]}),
("Show me Staff training cost for all accounting_flag ",{"entities":[(8,27,"Measure"),(36,51,"Categorical Dimension")]}),
("Show me length of service for all accounting_flag ",{"entities":[(8,25,"Measure"),(34,49,"Categorical Dimension")]}),
("Show me commission for all off_region ",{"entities":[(8,18,"Measure"),(27,37,"Categorical Dimension")]}),
("Show me workplace injuries for all fund_type_ind ",{"entities":[(8,26,"Measure"),(35,48,"Categorical Dimension")]}),
("Show me referral count for all StoreResults ",{"entities":[(8,22,"Measure"),(31,43,"Categorical Dimension"),(43,43,"Categorical Dimension")]}),
("Show me number of referrals for all pending ",{"entities":[(8,27,"Measure"),(36,43,"Categorical Dimension")]}),
("Show me claims payment for all new_items ",{"entities":[(8,22,"Measure"),(31,40,"Categorical Dimension")]}),
("Show me commission payment for all Claim severity ",{"entities":[(8,26,"Measure"),(35,49,"Categorical Dimension")]}),
("Show me overtime payment for all Product Name ",{"entities":[(8,24,"Measure"),(33,45,"Categorical Dimension")]}),
("Show me churn rate for all Product type ",{"entities":[(8,18,"Measure"),(27,39,"Categorical Dimension")]}),
("Show me employee turnover for all Product category ",{"entities":[(8,25,"Measure"),(34,50,"Categorical Dimension")]}),
("Show me overtime for all Claim status ",{"entities":[(8,16,"Measure"),(25,37,"Categorical Dimension")]}),
("Show me referral incentive for all Claim type ",{"entities":[(8,26,"Measure"),(35,45,"Categorical Dimension")]}),
("Show me LOP for all Basis ",{"entities":[(8,11,"Measure"),(20,25,"Categorical Dimension")]}),
("Show me Loss of Pay for all Policy Ref ",{"entities":[(0,0,"Categorical Dimension"),(8,19,"Measure"),(28,38,"Categorical Dimension")]}),
("Show me FTE count for all Insd ",{"entities":[(26,30,"Categorical Dimension")]}),
("Show me FTE vacancy count for all Risk Code Pol ",{"entities":[(8,25,"Measure"),(34,47,"Categorical Dimension")]}),
("Show me vacancy count for all Group Risk Code ",{"entities":[(8,21,"Measure"),(30,45,"Categorical Dimension")]}),
("Show me vacancy for all BPC Code ",{"entities":[(8,15,"Measure"),(24,32,"Categorical Dimension")]}),
("Show me filled vacancies for all Division ",{"entities":[(8,24,"Measure"),(33,41,"Categorical Dimension")]}),
("Show me open vacancies for all Office ",{"entities":[(8,22,"Measure"),(31,37,"Categorical Dimension")]}),
("Show me joining bonus for all Vertical ",{"entities":[(8,21,"Measure"),(29,38,"Categorical Dimension")]}),
("Show me notice period for all department ",{"entities":[(8,21,"Measure"),(30,40,"Categorical Dimension")]}),
("Show me relocation charges for all service line ",{"entities":[(8,26,"Measure"),(35,47,"Categorical Dimension")]}),
("Show me number of requisitions for all Horizontal ",{"entities":[(8,30,"Measure"),(39,49,"Categorical Dimension")]}),
("Show me number of resignations for all Vertical ",{"entities":[(8,30,"Measure"),(39,47,"Categorical Dimension")]}),
("Show me number of promotions for all Geography ",{"entities":[(8,28,"Measure"),(37,46,"Categorical Dimension")]}),
("Show me number of enrollments for all Sub-business group ",{"entities":[(8,29,"Measure"),(37,56,"Categorical Dimension")]}),
("Show me workforce tenure for all Business Group ",{"entities":[(8,24,"Measure"),(32,47,"Categorical Dimension")]}),
("Show me workforce for all Stream ",{"entities":[(8,17,"Measure"),(26,32,"Categorical Dimension")]}),
("Show me headcount for all Revenue Type ",{"entities":[(8,17,"Measure"),(26,38,"Categorical Dimension")]}),
("Show me Expected YTD for all department ",{"entities":[(9,21,"Goal Measure"),(29,39,"Categorical Dimension")]}),
("Show me Quoted EPI for all service line ",{"entities":[(8,18,"Goal Measure"),(27,39,"Categorical Dimension")]}),
("Show me Forecast Premium for all Horizontal ",{"entities":[(9,25,"Goal Measure"),(33,43,"Categorical Dimension")]}),
("Show me Overheads Budget for all Vertical ",{"entities":[(8,24,"Goal Measure"),(33,41,"Categorical Dimension")]}),
("Show me Forecast Premium for all Geography ",{"entities":[(8,24,"Goal Measure"),(33,42,"Categorical Dimension")]}),
("Show me Revenue Target for all Sub-business group ",{"entities":[(8,22,"Goal Measure"),(31,49,"Categorical Dimension")]}),
("Show me EBITDA Budget for all Business Group ",{"entities":[(8,21,"Goal Measure"),(30,44,"Categorical Dimension")]}),
("Show me target headcount for all Stream ",{"entities":[(8,24,"Goal Measure"),(33,39,"Categorical Dimension")]}),
("Show me Revenue Budget for all Revenue Type ",{"entities":[(8,22,"Goal Measure"),(30,42,"Categorical Dimension")]}),
("Show me completed_mtd for all Product class",{"entities":[(8,21,"Measure"),(30,43,"Categorical Dimension")]}),
("Show me completed_items for all Product type ",{"entities":[(8,23,"Measure"),(32,44,"Categorical Dimension")]}),
("Show me AUM for all Product category ",{"entities":[(8,11,"Measure"),(20,36,"Categorical Dimension")]}),
("Show me AsOf_sales for all Carrier ",{"entities":[(8,18,"Measure"),(27,34,"Categorical Dimension")]}),
("Show me net_ytd for all managing agent ",{"entities":[(8,15,"Measure"),(24,38,"Categorical Dimension")]}),
("Show me net_today for all agent ",{"entities":[(8,17,"Measure"),(26,31,"Categorical Dimension")]}),
("Show me Net_Sales for all Claim status ",{"entities":[(8,17,"Measure"),(26,38,"Categorical Dimension")]}),
("Show me net_mtd for all Claim type ",{"entities":[(8,15,"Measure"),(24,34,"Categorical Dimension")]}),
("Show me Net_AFB for all Age group ",{"entities":[(8,15,"Measure"),(24,33,"Categorical Dimension")]}),
("Show me MTDNetSales for all Group ",{"entities":[(8,19,"Measure"),(28,33,"Categorical Dimension")]}),
("Show me mtd_sales_afb for all cohort ",{"entities":[(8,21,"Measure"),(0,0,"Categorical Dimension"),(30,36,"Categorical Dimension")]}),
("Show me mtd_sales for all Order status ",{"entities":[(8,17,"Measure"),(26,38,"Categorical Dimension")]}),
("Show me mtd_redem_afb for all Status ",{"entities":[(8,21,"Measure"),(30,36,"Categorical Dimension")]}),
("Show me mtd_redem for all Size ",{"entities":[(8,17,"Measure"),(26,30,"Categorical Dimension")]}),
("Show me mtd_percent for all Type ",{"entities":[(8,19,"Measure"),(28,32,"Categorical Dimension")]}),
("Show me mtd_net_flow for all Quality ",{"entities":[(8,20,"Measure"),(29,36,"Categorical Dimension")]}),
("Show me mtd_net for all Grade ",{"entities":[(8,15,"Measure"),(24,29,"Categorical Dimension")]}),
("Show me MTD% for all Class ",{"entities":[(8,12,"Measure"),(21,26,"Categorical Dimension")]}),
("Show me mtd for all Mode ",{"entities":[(8,11,"Measure"),(20,24,"Categorical Dimension")]}),
("Show me YTDNetSales for all Method ",{"entities":[(7,19,"Measure"),(28,34,"Categorical Dimension")]}),
("Show me ytd_sales_afb for all Channel ",{"entities":[(7,21,"Measure"),(30,37,"Categorical Dimension")]}),
("Show me ytd_sales for all Item ",{"entities":[(8,17,"Measure"),(26,30,"Categorical Dimension")]}),
("Show me ytd_redem_afb for all Department ",{"entities":[(8,21,"Measure"),(30,40,"Categorical Dimension")]}),
("Show me ytd_redem for all order type ",{"entities":[(8,17,"Measure"),(26,36,"Categorical Dimension")]}),
("Show me ytd_percent for all Section ",{"entities":[(8,19,"Measure"),(28,35,"Categorical Dimension")]}),
("Show me ytd_net_flow for all Division ",{"entities":[(8,20,"Measure"),(29,37,"Categorical Dimension")]}),
("Show me ytd_net for all Brand ",{"entities":[(8,15,"Measure"),(24,29,"Categorical Dimension")]}),
("Show me YTD% for all Category ",{"entities":[(8,12,"Measure"),(21,29,"Categorical Dimension")]}),
("Show me ytd for all Lines ",{"entities":[(8,11,"Measure"),(20,25,"Categorical Dimension")]}),
("Show me usd_amt for all Store ",{"entities":[(8,15,"Measure"),(24,29,"Categorical Dimension")]}),
("Show me total_sales_afb for all store name ",{"entities":[(8,23,"Measure"),(32,42,"Categorical Dimension")]}),
("Show me total_sales for all Zones ",{"entities":[(8,19,"Measure"),(28,33,"Categorical Dimension")]}),
("Show me total_redem_afb for all Block ",{"entities":[(8,23,"Measure"),(32,37,"Categorical Dimension")]}),
("Show me total_redem for all Region ",{"entities":[(8,19,"Measure"),(28,34,"Categorical Dimension")]}),
("Show me total_pending for all State ",{"entities":[(8,21,"Measure"),(30,35,"Categorical Dimension")]}),
("Show me today_sales_afb for all City ",{"entities":[(8,23,"Measure"),(32,36,"Categorical Dimension")]}),
("Show me today_sales for all Country ",{"entities":[(8,19,"Measure"),(28,35,"Categorical Dimension")]}),
("Show me today_redem_afb for all Location ",{"entities":[(8,23,"Measure"),(32,40,"Categorical Dimension")]}),
("Show me today_redem for all length of service slabs ",{"entities":[(8,19,"Measure"),(28,51,"Categorical Dimension")]}),
("Show me today_net_flow for all employee performance ",{"entities":[(9,22,"Measure"),(31,51,"Categorical Dimension")]}),
("Show me today_net for all source ",{"entities":[(8,17,"Measure"),(26,32,"Categorical Dimension")]}),
("Show me today for all business unit ",{"entities":[(8,13,"Measure"),(22,35,"Categorical Dimension")]}),
("Show me sales_afb for all zone ",{"entities":[(8,17,"Measure"),(26,30,"Categorical Dimension")]}),
("Show me sales for all gender ",{"entities":[(8,13,"Measure"),(22,28,"Categorical Dimension")]}),
("Show me redemptions_afb for all years of service ",{"entities":[(8,23,"Measure"),(32,48,"Categorical Dimension")]}),
("Show me redemptions for all position ",{"entities":[(8,19,"Measure"),(28,36,"Categorical Dimension")]}),
("Show me QTDNetSales for all department ",{"entities":[(8,19,"Measure"),(28,38,"Categorical Dimension")]}),
("Show me qtd_sales for all hierarchy ",{"entities":[(8,17,"Measure"),(26,35,"Categorical Dimension")]}),
("Show me qtd_redem for all location ",{"entities":[(8,17,"Measure"),(26,34,"Categorical Dimension")]}),
("Show me pyr_redem for all division ",{"entities":[(8,17,"Measure"),(26,34,"Categorical Dimension")]}),
("Show me pyr_net for all service group ",{"entities":[(8,15,"Measure"),(24,37,"Categorical Dimension")]}),
("Show me avg policy size for all age group ",{"entities":[(8,23,"Measure"),(32,41,"Categorical Dimension")]}),
("Show me underwriting speed for all levels ",{"entities":[(8,26,"Measure"),(35,41,"Categorical Dimension")]}),
("Show me cost per claim for all grade ",{"entities":[(8,22,"Measure"),(31,36,"Categorical Dimension")]}),
("Show me number of referrals for all accounting_flag ",{"entities":[(8,27,"Measure"),(36,51,"Categorical Dimension")]}),
("Show me Premium for all accounting_flag ",{"entities":[(8,15,"Measure"),(24,39,"Categorical Dimension")]}),
("Show me Payout for all off_region ",{"entities":[(8,14,"Measure"),(23,33,"Categorical Dimension")]}),
("Show me Submitted EPI for all fund_type_ind ",{"entities":[(8,21,"Measure"),(29,43,"Categorical Dimension")]}),
("Show me Actual EPI YTD for all StoreResults ",{"entities":[(8,22,"Measure"),(31,43,"Categorical Dimension")]}),
("Show me time to settle a claim for all pending ",{"entities":[(8,30,"Measure"),(39,46,"Categorical Dimension")]}),
("Show me Budget Premium for all new_items ",{"entities":[(8,22,"Measure"),(31,40,"Categorical Dimension")]}),
("Show me PY Actual YTD for all Claim severity ",{"entities":[(7,17,"Measure"),(26,40,"Categorical Dimension")]}),
("Show me Policy Count for all Product Name ",{"entities":[(8,20,"Measure"),(29,41,"Categorical Dimension")]}),
("Show me Limit Remaining for all Product type ",{"entities":[(8,23,"Measure"),(32,44,"Categorical Dimension")]}),
("Show me Plan Remaining for all Product category ",{"entities":[(8,22,"Measure"),(31,47,"Categorical Dimension")]}),
("Show me Plan Remaining % for all Claim status ",{"entities":[(8,24,"Measure"),(33,45,"Categorical Dimension")]}),
("Show me Claim Movement for all Claim type ",{"entities":[(8,22,"Measure"),(31,41,"Categorical Dimension")]}),
("Show me Expiring EPI for all Basis ",{"entities":[(7,20,"Measure"),(29,34,"Categorical Dimension")]}),
("Show me Lost / Lapsed EPI for all Policy Ref ",{"entities":[(7,25,"Measure"),(34,44,"Categorical Dimension")]}),
("Show me Lapsed EPI for all Insd ",{"entities":[(8,18,"Measure"),(27,31,"Categorical Dimension")]}),
("Show me Declinature & NTU EPI for all Risk Code Pol ",{"entities":[(8,29,"Measure"),(38,51,"Categorical Dimension")]}),
("Show me Bound Premium for all Group Risk Code ",{"entities":[(8,21,"Measure"),(30,45,"Categorical Dimension")]}),
("Show me Var % YoY for all BPC Code ",{"entities":[(8,17,"Measure"),(26,34,"Categorical Dimension")]}),
("Show me Var Plan Used % for all Division ",{"entities":[(8,23,"Measure"),(32,40,"Categorical Dimension")]}),
("Show me Benchmark Adequacy for all Office ",{"entities":[(8,26,"Measure"),(35,41,"Categorical Dimension")]}),
("Show me Tech Adequacy for all Vertical ",{"entities":[(8,21,"Measure"),(30,38,"Categorical Dimension")]}),
("Show me Attrition / Attr GILR for all department ",{"entities":[(8,29,"Measure"),(38,48,"Categorical Dimension")]}),
("Show me Loss Ratio / GILR for all service line ",{"entities":[(8,25,"Measure"),(34,46,"Categorical Dimension")]}),
("Show me Yet to Renew for all Horizontal ",{"entities":[(8,20,"Measure"),(29,39,"Categorical Dimension")]}),
("Show me (PY) Prior Yr YTD for all Vertical ",{"entities":[(8,20,"Measure"),(29,37,"Categorical Dimension")]}),
("Show me  Actual YTD for all Geography ",{"entities":[(7,18,"Measure"),(27,36,"Categorical Dimension")]}),
("Show me Prior Yr YOY for all Sub-business group ",{"entities":[(7,20,"Measure"),(29,47,"Categorical Dimension")]}),
("Show me Variance to Prior Year for all Business Group",{"entities":[(8,30,"Measure"),(39,53,"Categorical Dimension")]}),
("Show me Renewal % for all Stream ",{"entities":[(8,17,"Measure"),(26,32,"Categorical Dimension")]}),
("Show me New % for all Revenue Type ",{"entities":[(8,13,"Measure"),(22,34,"Categorical Dimension")]}),
("what is my pyr_net across different service group ",{"entities":[(11,18,"Measure"),(36,49,"Categorical Dimension")]}),
("what is my avg policy size across different age group ",{"entities":[(11,26,"Measure"),(44,53,"Categorical Dimension")]}),
("what is my underwriting speed across different levels ",{"entities":[(11,29,"Measure"),(47,53,"Categorical Dimension")]}),
("what is my cost per claim across different grade ",{"entities":[(11,25,"Measure"),(43,48,"Categorical Dimension")]}),
("what is my number of referrals across different accounting_flag ",{"entities":[(11,30,"Measure"),(48,63,"Categorical Dimension")]}),
("what is my Premium across different accounting_flag ",{"entities":[(11,18,"Measure"),(36,51,"Categorical Dimension")]}),
("what is my Payout across different off_region ",{"entities":[(11,17,"Measure"),(35,45,"Categorical Dimension")]}),
("what is my Submitted EPI across different fund_type_ind ",{"entities":[(11,24,"Measure"),(42,55,"Categorical Dimension")]}),
("what is my Actual EPI YTD across different StoreResults ",{"entities":[(11,26,"Measure"),(43,55,"Categorical Dimension")]}),
("what is my time to settle a claim across different pending ",{"entities":[(11,33,"Measure"),(51,58,"Categorical Dimension")]}),
("what is my Budget Premium across different new_items ",{"entities":[(11,25,"Measure"),(43,52,"Categorical Dimension")]}),
("what is my PY Actual YTD across different Claim severity ",{"entities":[(11,24,"Measure"),(42,56,"Categorical Dimension")]}),
("what is my Policy Count across different Product Name ",{"entities":[(11,23,"Measure"),(41,53,"Categorical Dimension")]}),
("what is my Limit Remaining across different Product type ",{"entities":[(11,26,"Measure"),(44,56,"Categorical Dimension")]}),
("what is my Plan Remaining across different Product category ",{"entities":[(11,25,"Measure"),(43,59,"Categorical Dimension")]}),
("what is my Plan Remaining % across different Claim status ",{"entities":[(-4,0,"Measure"),(11,27,"Measure"),(45,57,"Categorical Dimension")]}),
("what is my Claim Movement across different Claim type ",{"entities":[(11,25,"Measure"),(43,53,"Categorical Dimension")]}),
("what is my Expiring EPI across different Basis ",{"entities":[(11,23,"Measure"),(41,46,"Categorical Dimension")]}),
("what is my Lost / Lapsed EPI across different Policy Ref ",{"entities":[(11,28,"Measure"),(46,56,"Categorical Dimension")]}),
("what is my Lapsed EPI across different Insd ",{"entities":[(11,21,"Measure"),(39,43,"Categorical Dimension")]}),
("what is my Declinature & NTU EPI across different Risk Code Pol ",{"entities":[(11,32,"Measure"),(50,63,"Categorical Dimension")]}),
("what is my Bound Premium across different Group Risk Code ",{"entities":[(11,25,"Measure"),(42,57,"Categorical Dimension")]}),
("what is my Var % YoY across different BPC Code ",{"entities":[(11,21,"Measure"),(38,46,"Categorical Dimension")]}),
("what is my Var Plan Used % across different Division ",{"entities":[(11,26,"Measure"),(44,52,"Categorical Dimension")]}),
("what is my Benchmark Adequacy across different Office ",{"entities":[(11,29,"Measure"),(47,53,"Categorical Dimension")]}),
("what is my Tech Adequacy across different Vertical ",{"entities":[(11,24,"Measure"),(42,50,"Categorical Dimension")]}),
("what is my Attrition / Attr GILR across different department ",{"entities":[(11,32,"Measure"),(50,60,"Categorical Dimension")]}),
("what is my Loss Ratio / GILR across different service line ",{"entities":[(11,28,"Measure"),(46,58,"Categorical Dimension")]}),
("what is my Yet to Renew across different Horizontal ",{"entities":[(11,23,"Measure"),(41,51,"Categorical Dimension")]}),
("what is my Prior Yr YTD across different Vertical ",{"entities":[(12,24,"Measure"),(41,49,"Categorical Dimension")]}),
("what is my Actual YTD across different Geography ",{"entities":[(12,22,"Measure"),(39,48,"Categorical Dimension")]}),
("what is my Prior Yr YOY across different Sub-business group ",{"entities":[(11,23,"Measure"),(41,59,"Categorical Dimension")]}),
("what is my Variance to Prior Year across different Business Group ",{"entities":[(12,34,"Measure"),(51,65,"Categorical Dimension")]}),
("what is my Renewal % across different Stream ",{"entities":[(11,20,"Measure"),(38,44,"Categorical Dimension")]}),
("what is my New % across different Revenue Type ",{"entities":[(11,16,"Measure"),(34,46,"Categorical Dimension")]}),
("what is my Rate Chg % across different portfolio ",{"entities":[(11,21,"Measure"),(39,48,"Categorical Dimension")]}),
("what is my Retention % across different client ",{"entities":[(11,22,"Measure"),(40,46,"Categorical Dimension")]}),
("what is my Bound Premium across different risk group ",{"entities":[(11,24,"Measure"),(42,52,"Categorical Dimension")]}),
("what is my Overheads across different broker ",{"entities":[(11,20,"Measure"),(37,44,"Categorical Dimension")]}),
("what is my EBITDA across different lloyd's broker ",{"entities":[(11,18,"Measure"),(35,49,"Categorical Dimension")]}),
("what is my Revenue per day across different event ",{"entities":[(11,26,"Measure"),(44,49,"Categorical Dimension")]}),
("what is my Net Profit Margin across different accounting classes ",{"entities":[(11,28,"Measure"),(46,64,"Categorical Dimension")]}),
("what is my GM across different Claim severity ",{"entities":[(11,13,"Measure"),(31,45,"Categorical Dimension")]}),
("what is my Gross Margin across different policy holder ",{"entities":[(11,23,"Measure"),(40,54,"Categorical Dimension")]}),
("what is my Expense across different policy type ",{"entities":[(11,18,"Measure"),(36,47,"Categorical Dimension")]}),
("what is my Revenue across different policy ",{"entities":[(11,18,"Measure"),(36,42,"Categorical Dimension")]}),
("what is my Growth% across different Product Name ",{"entities":[(11,18,"Measure"),(36,48,"Categorical Dimension")]}),
("what is my attrition rate across different Product class ",{"entities":[(11,25,"Measure"),(42,56,"Categorical Dimension")]}),
("what is my layover across different Product type ",{"entities":[(11,18,"Measure"),(36,48,"Categorical Dimension")]}),
("what is my retention rate across different Product category ",{"entities":[(11,25,"Measure"),(43,59,"Categorical Dimension")]}),
("what is my training period across different Carrier ",{"entities":[(11,27,"Measure"),(44,51,"Categorical Dimension")]}),
("what is my ctc across different managing agent ",{"entities":[(11,14,"Measure"),(32,46,"Categorical Dimension")]}),
("what is my time to fill across different agent ",{"entities":[(11,23,"Measure"),(41,46,"Categorical Dimension")]}),
("what is my number of hires across different Claim status ",{"entities":[(11,26,"Measure"),(44,56,"Categorical Dimension")]}),
("what is my number of recruitments across different Claim type ",{"entities":[(11,33,"Measure"),(51,61,"Categorical Dimension")]}),
("what is my recruitment cost across different Age group ",{"entities":[(11,27,"Measure"),(45,54,"Categorical Dimension")]}),
("what is my training days across different Group ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my training cost across different cohort ",{"entities":[(11,24,"Measure"),(42,48,"Categorical Dimension")]}),
("what is my variable pay across different Order status ",{"entities":[(11,23,"Measure"),(41,53,"Categorical Dimension")]}),
("what is my fixed pay across different Status ",{"entities":[(11,21,"Measure"),(38,44,"Categorical Dimension")]}),
("what is my bonus across different Size ",{"entities":[(11,16,"Measure"),(34,38,"Categorical Dimension")]}),
("what is my working hours across different Type ",{"entities":[(11,24,"Measure"),(42,46,"Categorical Dimension")]}),
("what is my experience across different Quality ",{"entities":[(11,21,"Measure"),(39,46,"Categorical Dimension")]}),
("what is my Sick leaves across different Grade ",{"entities":[(11,22,"Measure"),(40,45,"Categorical Dimension")]}),
("what is my earned leaves across different Class ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my salary across different Mode ",{"entities":[(11,17,"Measure"),(35,39,"Categorical Dimension")]}),
("what is my number of employees across different Method ",{"entities":[(11,30,"Measure"),(48,54,"Categorical Dimension")]}),
("what is my dividend rate across different Channel ",{"entities":[(11,24,"Measure"),(42,49,"Categorical Dimension")]}),
("what is my dividend across different Item ",{"entities":[(11,19,"Measure"),(37,41,"Categorical Dimension")]}),
("what is my D/E Ratio across different Department ",{"entities":[(11,20,"Measure"),(38,48,"Categorical Dimension")]}),
("what is my CAPEX across different order type ",{"entities":[(11,16,"Measure"),(34,44,"Categorical Dimension")]}),
("what is my OPEX across different Section ",{"entities":[(11,15,"Measure"),(33,40,"Categorical Dimension")]}),
("what is my Turnover across different Division ",{"entities":[(11,19,"Measure"),(37,45,"Categorical Dimension")]}),
("what is my Working Capital across different Brand ",{"entities":[(11,27,"Measure"),(44,49,"Categorical Dimension")]}),
("what is my Burn rate across different Category ",{"entities":[(11,21,"Measure"),(38,46,"Categorical Dimension")]}),
("what is my OCF across different Lines ",{"entities":[(11,14,"Measure"),(32,37,"Categorical Dimension")]}),
("what is my Operating Cash Flow across different Store ",{"entities":[(11,30,"Measure"),(48,53,"Categorical Dimension")]}),
("what is my EBIT% across different store name ",{"entities":[(11,16,"Measure"),(34,44,"Categorical Dimension")]}),
("what is my EBITDA% across different Zones ",{"entities":[(11,18,"Measure"),(36,41,"Categorical Dimension")]}),
("what is my Operating Profit% across different Block ",{"entities":[(11,28,"Measure"),(46,51,"Categorical Dimension")]}),
("what is my GM% across different Region ",{"entities":[(11,14,"Measure"),(32,38,"Categorical Dimension")]}),
("what is my Gross Margin% across different State ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my Profit Margin% across different City ",{"entities":[(11,25,"Measure"),(43,47,"Categorical Dimension")]}),
("what is my Profit% across different Country ",{"entities":[(11,18,"Measure"),(36,43,"Categorical Dimension")]}),
("what is my Profit across different Location ",{"entities":[(11,17,"Measure"),(35,43,"Categorical Dimension")]}),
("what is my Loss% across different length of service slabs ",{"entities":[(11,16,"Measure"),(34,57,"Categorical Dimension")]}),
("what is my Loss across different employee performance ",{"entities":[(11,15,"Measure"),(33,53,"Categorical Dimension")]}),
("what is my Tax across different source ",{"entities":[(11,14,"Measure"),(32,38,"Categorical Dimension")]}),
("what is my Interest rate across different business unit ",{"entities":[(11,24,"Measure"),(42,55,"Categorical Dimension")]}),
("what is my Exceptionals across different zone ",{"entities":[(11,23,"Measure"),(41,45,"Categorical Dimension")]}),
("what is my Monitoring costs across different gender ",{"entities":[(11,27,"Measure"),(45,51,"Categorical Dimension")]}),
("what is my Direct Cost across different years of service ",{"entities":[(11,23,"Measure"),(40,56,"Categorical Dimension")]}),
("what is my Depreciation across different position ",{"entities":[(11,23,"Measure"),(41,49,"Categorical Dimension")]}),
("what is my Other income across different department ",{"entities":[(11,23,"Measure"),(41,51,"Categorical Dimension")]}),
("what is my EBIT across different hierarchy ",{"entities":[(10,15,"Measure"),(33,42,"Categorical Dimension")]}),
("what is my Operating Income across different location ",{"entities":[(11,27,"Measure"),(45,53,"Categorical Dimension")]}),
("what is my Operating Profit across different division ",{"entities":[(11,27,"Measure"),(45,53,"Categorical Dimension")]}),
("what is my Cost of Sales across different service group ",{"entities":[(11,24,"Measure"),(42,55,"Categorical Dimension")]}),
("what is my vacation days across different age group ",{"entities":[(11,24,"Measure"),(42,51,"Categorical Dimension")]}),
("what is my leavers across different levels ",{"entities":[(11,18,"Measure"),(36,42,"Categorical Dimension")]}),
("what is my work tenure across different grade ",{"entities":[(11,22,"Measure"),(40,45,"Categorical Dimension")]}),
("what is my Staff training cost across different accounting_flag ",{"entities":[(11,30,"Measure"),(48,63,"Categorical Dimension")]}),
("what is my length of service across different accounting_flag ",{"entities":[(11,28,"Measure"),(46,61,"Categorical Dimension")]}),
("what is my commission across different off_region ",{"entities":[(11,21,"Measure"),(39,49,"Categorical Dimension")]}),
("what is my workplace injuries across different fund_type_ind ",{"entities":[(11,29,"Measure"),(47,60,"Categorical Dimension")]}),
("what is my referral count across different StoreResults ",{"entities":[(11,25,"Measure"),(43,55,"Categorical Dimension")]}),
("what is my number of referrals across different pending ",{"entities":[(11,30,"Measure"),(48,55,"Categorical Dimension")]}),
("what is my claims payment across different new_items ",{"entities":[(11,25,"Measure"),(43,52,"Categorical Dimension")]}),
("what is my commission payment across different Claim severity ",{"entities":[(11,29,"Measure"),(47,61,"Categorical Dimension")]}),
("what is my overtime payment across different Product Name ",{"entities":[(11,27,"Measure"),(45,57,"Categorical Dimension")]}),
("what is my churn rate across different Product type ",{"entities":[(11,21,"Measure"),(39,51,"Categorical Dimension")]}),
("what is my employee turnover across different Product category ",{"entities":[(11,28,"Measure"),(46,62,"Categorical Dimension")]}),
("what is my overtime across different Claim status ",{"entities":[(11,19,"Measure"),(37,49,"Categorical Dimension")]}),
("what is my referral incentive across different Claim type ",{"entities":[(11,29,"Measure"),(47,57,"Categorical Dimension")]}),
("what is my LOP across different Basis ",{"entities":[(11,14,"Measure"),(32,37,"Categorical Dimension")]}),
("what is my Loss of Pay across different Policy Ref ",{"entities":[(11,22,"Measure"),(40,50,"Categorical Dimension")]}),
("what is my FTE count across different Insd ",{"entities":[(11,20,"Measure"),(38,42,"Categorical Dimension")]}),
("what is my FTE vacancy count across different Risk Code Pol ",{"entities":[(11,28,"Measure"),(46,59,"Categorical Dimension")]}),
("what is my vacancy count across different Group Risk Code ",{"entities":[(10,24,"Measure"),(42,57,"Categorical Dimension")]}),
("what is my vacancy across different BPC Code ",{"entities":[(11,18,"Measure"),(36,44,"Categorical Dimension")]}),
("what is my filled vacancies across different Division ",{"entities":[(11,27,"Measure"),(45,53,"Categorical Dimension")]}),
("what is my open vacancies across different Office ",{"entities":[(11,25,"Measure"),(43,49,"Categorical Dimension")]}),
("what is my joining bonus across different Vertical ",{"entities":[(11,24,"Measure"),(42,50,"Categorical Dimension")]}),
("what is my notice period across different department ",{"entities":[(11,24,"Measure"),(42,52,"Categorical Dimension")]}),
("what is my relocation charges across different service line ",{"entities":[(11,29,"Measure"),(47,59,"Categorical Dimension")]}),
("what is my number of requisitions across different Horizontal ",{"entities":[(11,33,"Measure"),(51,61,"Categorical Dimension")]}),
("what is my number of resignations across different Vertical ",{"entities":[(11,33,"Measure"),(51,59,"Categorical Dimension")]}),
("what is my number of promotions across different Geography ",{"entities":[(11,31,"Measure"),(49,58,"Categorical Dimension")]}),
("what is my number of enrollments across different Sub-business group ",{"entities":[(11,32,"Measure"),(50,68,"Categorical Dimension")]}),
("what is my workforce tenure across different Business Group ",{"entities":[(11,27,"Measure"),(45,59,"Categorical Dimension")]}),
("what is my workforce across different Stream ",{"entities":[(11,20,"Measure"),(38,44,"Categorical Dimension")]}),
("what is my headcount across different Revenue Type ",{"entities":[(11,21,"Measure"),(38,50,"Categorical Dimension")]}),
("what is my completed_mtd across different Product class ",{"entities":[(11,24,"Measure"),(42,55,"Categorical Dimension")]}),
("what is my completed_items across different Product type ",{"entities":[(11,26,"Measure"),(44,56,"Categorical Dimension")]}),
("what is my AUM across different Product category ",{"entities":[(11,14,"Measure"),(32,48,"Categorical Dimension")]}),
("what is my AsOf_sales across different Carrier ",{"entities":[(11,21,"Measure"),(39,46,"Categorical Dimension")]}),
("what is my net_ytd across different managing agent ",{"entities":[(11,18,"Measure"),(45,50,"Categorical Dimension")]}),
("what is my net_today across different agent ",{"entities":[(11,20,"Measure"),(38,43,"Categorical Dimension")]}),
("what is my Net_Sales across different Claim status ",{"entities":[(11,20,"Measure"),(38,50,"Categorical Dimension")]}),
("what is my net_mtd across different Claim type ",{"entities":[(11,18,"Measure"),(36,46,"Categorical Dimension")]}),
("what is my Net_AFB across different Age group ",{"entities":[(11,18,"Measure"),(36,45,"Categorical Dimension")]}),
("what is my MTDNetSales across different Group ",{"entities":[(11,22,"Measure")]}),
("what is my mtd_sales_afb across different cohort ",{"entities":[(11,24,"Measure"),(42,48,"Categorical Dimension")]}),
("what is my mtd_sales across different Order status ",{"entities":[(11,20,"Measure"),(38,50,"Categorical Dimension")]}),
("what is my mtd_redem_afb across different Status ",{"entities":[(11,24,"Measure"),(42,48,"Categorical Dimension")]}),
("what is my mtd_redem across different Size ",{"entities":[(11,20,"Measure"),(38,42,"Categorical Dimension")]}),
("what is my mtd_percent across different Type ",{"entities":[(11,22,"Measure"),(40,44,"Categorical Dimension")]}),
("what is my mtd_net_flow across different Quality ",{"entities":[(11,23,"Measure"),(41,48,"Categorical Dimension")]}),
("what is my mtd_net across different Grade ",{"entities":[(11,18,"Measure"),(36,41,"Categorical Dimension")]}),
("what is my MTD% across different Class ",{"entities":[(11,15,"Measure"),(33,38,"Categorical Dimension")]}),
("what is my mtd across different Mode ",{"entities":[(11,14,"Measure"),(32,36,"Categorical Dimension")]}),
("what is my YTDNetSales across different Method ",{"entities":[(11,22,"Measure"),(40,46,"Categorical Dimension")]}),
("what is my ytd_sales_afb across different Channel ",{"entities":[(11,24,"Measure"),(42,49,"Categorical Dimension")]}),
("what is my ytd_sales across different Item ",{"entities":[(11,20,"Measure"),(38,42,"Categorical Dimension")]}),
("what is my ytd_redem_afb across different Department ",{"entities":[(11,24,"Measure"),(42,52,"Categorical Dimension")]}),
("what is my ytd_redem across different order type ",{"entities":[(11,20,"Measure"),(38,48,"Categorical Dimension")]}),
("what is my ytd_percent across different Section ",{"entities":[(11,22,"Measure"),(40,47,"Categorical Dimension")]}),
("what is my ytd_net_flow across different Division ",{"entities":[(11,23,"Measure"),(41,49,"Categorical Dimension")]}),
("what is my ytd_net across different Brand ",{"entities":[(36,41,"Categorical Dimension")]}),
("what is my YTD% across different Category ",{"entities":[(11,15,"Measure"),(33,41,"Categorical Dimension")]}),
("what is my ytd across different Lines ",{"entities":[(11,14,"Measure"),(32,37,"Categorical Dimension")]}),
("what is my usd_amt across different Store ",{"entities":[(11,18,"Measure"),(36,41,"Categorical Dimension")]}),
("what is my total_sales_afb across different store name ",{"entities":[(11,26,"Measure"),(44,54,"Categorical Dimension")]}),
("what is my total_sales across different Zones ",{"entities":[(11,22,"Measure"),(40,45,"Categorical Dimension")]}),
("what is my total_redem_afb across different Block ",{"entities":[(11,26,"Measure"),(0,0,"Categorical Dimension"),(44,49,"Categorical Dimension")]}),
("what is my total_redem across different Region ",{"entities":[(11,22,"Measure"),(40,46,"Categorical Dimension")]}),
("what is my total_pending across different State ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my today_sales_afb across different City ",{"entities":[(11,26,"Measure"),(44,48,"Categorical Dimension")]}),
("what is my today_sales across different Country ",{"entities":[(11,22,"Measure"),(40,47,"Categorical Dimension")]}),
("what is my today_redem_afb across different Location ",{"entities":[(11,26,"Measure"),(44,52,"Categorical Dimension")]}),
("what is my today_redem across different length of service slabs ",{"entities":[(11,22,"Measure"),(40,63,"Categorical Dimension")]}),
("what is my today_net_flow across different employee performance ",{"entities":[(11,25,"Measure"),(43,63,"Categorical Dimension")]}),
("what is my today_net across different source ",{"entities":[(11,20,"Measure"),(38,44,"Categorical Dimension")]}),
("what is my today across different business unit ",{"entities":[(11,16,"Measure"),(34,47,"Categorical Dimension")]}),
("what is my sales_afb across different zone ",{"entities":[(11,20,"Measure"),(37,42,"Categorical Dimension")]}),
("what is my sales across different gender ",{"entities":[(11,16,"Measure"),(34,40,"Categorical Dimension")]}),
("what is my redemptions_afb across different years of service ",{"entities":[(11,27,"Measure"),(44,60,"Categorical Dimension")]}),
("what is my redemptions across different position ",{"entities":[(11,22,"Measure"),(40,48,"Categorical Dimension")]}),
("what is my QTDNetSales across different department ",{"entities":[(11,22,"Measure"),(40,50,"Categorical Dimension")]}),
("what is my qtd_sales across different hierarchy ",{"entities":[(11,20,"Measure"),(38,47,"Categorical Dimension")]}),
("what is my qtd_redem across different location ",{"entities":[(11,20,"Measure"),(38,46,"Categorical Dimension")]}),
("what is my pyr_redem across different division ",{"entities":[(11,20,"Measure"),(38,46,"Categorical Dimension")]}),
("what is my pyr_net across different service group ",{"entities":[(11,18,"Measure"),(36,49,"Categorical Dimension")]}),
("what is my avg policy size across different age group ",{"entities":[(11,26,"Measure"),(44,53,"Categorical Dimension")]}),
("what is my underwriting speed across different levels ",{"entities":[(11,29,"Measure"),(47,53,"Categorical Dimension")]}),
("what is my cost per claim across different grade ",{"entities":[(11,25,"Measure"),(43,48,"Categorical Dimension")]}),
("what is my number of referrals across different accounting_flag ",{"entities":[(11,30,"Measure"),(48,63,"Categorical Dimension")]}),
("what is my Premium across different accounting_flag ",{"entities":[(11,18,"Measure"),(36,51,"Categorical Dimension")]}),
("what is my Payout across different off_region ",{"entities":[(11,17,"Measure"),(35,45,"Categorical Dimension")]}),
("what is my Submitted EPI across different fund_type_ind ",{"entities":[(11,24,"Measure"),(42,55,"Categorical Dimension")]}),
("what is my Actual EPI YTD across different StoreResults ",{"entities":[(11,26,"Measure"),(43,55,"Categorical Dimension")]}),
("what is my time to settle a claim across different pending ",{"entities":[(11,33,"Measure"),(51,58,"Categorical Dimension")]}),
("what is my Budget Premium across different new_items ",{"entities":[(11,25,"Measure"),(43,52,"Categorical Dimension")]}),
("what is my PY Actual YTD across different Claim severity ",{"entities":[(11,24,"Measure"),(42,56,"Categorical Dimension")]}),
("what is my Policy Count across different Product Name ",{"entities":[(11,23,"Measure"),(41,53,"Categorical Dimension")]}),
("what is my Limit Remaining across different Product type ",{"entities":[(11,26,"Measure"),(44,56,"Categorical Dimension")]}),
("what is my Plan Remaining across different Product category ",{"entities":[(11,25,"Measure"),(43,59,"Categorical Dimension")]}),
("what is my Plan Remaining % across different Claim status ",{"entities":[(-4,0,"Measure"),(11,27,"Measure"),(45,57,"Categorical Dimension")]}),
("what is my Claim Movement across different Claim type ",{"entities":[(11,25,"Measure"),(43,53,"Categorical Dimension")]}),
("what is my Expiring EPI across different Basis ",{"entities":[(11,23,"Measure"),(41,46,"Categorical Dimension")]}),
("what is my Lost / Lapsed EPI across different Policy Ref ",{"entities":[(11,28,"Measure"),(46,56,"Categorical Dimension")]}),
("what is my Lapsed EPI across different Insd ",{"entities":[(11,21,"Measure"),(39,43,"Categorical Dimension")]}),
("what is my Declinature & NTU EPI across different Risk Code Pol ",{"entities":[(11,32,"Measure"),(50,63,"Categorical Dimension")]}),
("what is my Bound Premium across different Group Risk Code ",{"entities":[(11,25,"Measure"),(42,57,"Categorical Dimension")]}),
("what is my Var % YoY across different BPC Code ",{"entities":[(11,21,"Measure"),(38,46,"Categorical Dimension")]}),
("what is my Var Plan Used % across different Division ",{"entities":[(11,26,"Measure"),(44,52,"Categorical Dimension")]}),
("what is my Benchmark Adequacy across different Office ",{"entities":[(11,29,"Measure"),(47,53,"Categorical Dimension")]}),
("what is my Tech Adequacy across different Vertical ",{"entities":[(11,24,"Measure"),(42,50,"Categorical Dimension")]}),
("what is my Attrition / Attr GILR across different department ",{"entities":[(11,32,"Measure"),(50,60,"Categorical Dimension")]}),
("what is my Loss Ratio / GILR across different service line ",{"entities":[(11,28,"Measure"),(46,58,"Categorical Dimension")]}),
("what is my Yet to Renew across different Horizontal ",{"entities":[(11,23,"Measure"),(41,51,"Categorical Dimension")]}),
("what is my Prior Yr YTD across different Vertical ",{"entities":[(12,24,"Measure"),(41,49,"Categorical Dimension")]}),
("what is my Actual YTD across different Geography ",{"entities":[(12,22,"Measure"),(39,48,"Categorical Dimension")]}),
("what is my Prior Yr YOY across different Sub-business group ",{"entities":[(11,23,"Measure"),(41,59,"Categorical Dimension")]}),
("what is my Variance to Prior Year across different Business Group ",{"entities":[(12,34,"Measure"),(51,65,"Categorical Dimension")]}),
("what is my Renewal % across different Stream ",{"entities":[(11,20,"Measure"),(38,44,"Categorical Dimension")]}),
("what is my New % across different Revenue Type ",{"entities":[(11,16,"Measure"),(34,46,"Categorical Dimension")]}),
("what is my Rate Chg % across different portfolio ",{"entities":[(11,21,"Measure"),(39,48,"Categorical Dimension")]}),
("what is my Retention % across different client ",{"entities":[(11,22,"Measure"),(40,46,"Categorical Dimension")]}),
("what is my Bound Premium across different risk group ",{"entities":[(11,24,"Measure"),(42,52,"Categorical Dimension")]}),
("what is my Overheads across different broker ",{"entities":[(11,20,"Measure"),(37,44,"Categorical Dimension")]}),
("what is my EBITDA across different lloyd's broker ",{"entities":[(11,18,"Measure"),(35,49,"Categorical Dimension")]}),
("what is my Revenue per day across different event ",{"entities":[(11,26,"Measure"),(44,49,"Categorical Dimension")]}),
("what is my Net Profit Margin across different accounting classes ",{"entities":[(11,28,"Measure"),(46,64,"Categorical Dimension")]}),
("what is my GM across different Claim severity ",{"entities":[(11,13,"Measure"),(31,45,"Categorical Dimension")]}),
("what is my Gross Margin across different policy holder ",{"entities":[(11,23,"Measure"),(40,54,"Categorical Dimension")]}),
("what is my Expense across different policy type ",{"entities":[(11,18,"Measure"),(36,47,"Categorical Dimension")]}),
("what is my Revenue across different policy ",{"entities":[(11,18,"Measure"),(36,42,"Categorical Dimension")]}),
("what is my Growth% across different Product Name ",{"entities":[(11,18,"Measure"),(36,48,"Categorical Dimension")]}),
("what is my attrition rate across different Product class ",{"entities":[(11,25,"Measure"),(42,56,"Categorical Dimension")]}),
("what is my layover across different Product type ",{"entities":[(11,18,"Measure"),(36,48,"Categorical Dimension")]}),
("what is my retention rate across different Product category ",{"entities":[(11,25,"Measure"),(43,59,"Categorical Dimension")]}),
("what is my training period across different Carrier ",{"entities":[(11,27,"Measure"),(44,51,"Categorical Dimension")]}),
("what is my ctc across different managing agent ",{"entities":[(11,14,"Measure"),(32,46,"Categorical Dimension")]}),
("what is my time to fill across different agent ",{"entities":[(11,23,"Measure"),(41,46,"Categorical Dimension")]}),
("what is my number of hires across different Claim status ",{"entities":[(11,26,"Measure"),(44,56,"Categorical Dimension")]}),
("what is my number of recruitments across different Claim type ",{"entities":[(11,33,"Measure"),(51,61,"Categorical Dimension")]}),
("what is my recruitment cost across different Age group ",{"entities":[(11,27,"Measure"),(45,54,"Categorical Dimension")]}),
("what is my training days across different Group ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my training cost across different cohort ",{"entities":[(11,24,"Measure"),(42,48,"Categorical Dimension")]}),
("what is my variable pay across different Order status ",{"entities":[(11,23,"Measure"),(41,53,"Categorical Dimension")]}),
("what is my fixed pay across different Status ",{"entities":[(11,21,"Measure"),(38,44,"Categorical Dimension")]}),
("what is my bonus across different Size ",{"entities":[(11,16,"Measure"),(34,38,"Categorical Dimension")]}),
("what is my working hours across different Type ",{"entities":[(11,24,"Measure"),(42,46,"Categorical Dimension")]}),
("what is my experience across different Quality ",{"entities":[(11,21,"Measure"),(39,46,"Categorical Dimension")]}),
("what is my Sick leaves across different Grade ",{"entities":[(11,22,"Measure"),(40,45,"Categorical Dimension")]}),
("what is my earned leaves across different Class ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my salary across different Mode ",{"entities":[(11,17,"Measure"),(35,39,"Categorical Dimension")]}),
("what is my number of employees across different Method ",{"entities":[(11,30,"Measure"),(48,54,"Categorical Dimension")]}),
("what is my dividend rate across different Channel ",{"entities":[(11,24,"Measure"),(42,49,"Categorical Dimension")]}),
("what is my dividend across different Item ",{"entities":[(11,19,"Measure"),(37,41,"Categorical Dimension")]}),
("what is my D/E Ratio across different Department ",{"entities":[(11,20,"Measure"),(38,48,"Categorical Dimension")]}),
("what is my CAPEX across different order type ",{"entities":[(11,16,"Measure"),(34,44,"Categorical Dimension")]}),
("what is my OPEX across different Section ",{"entities":[(11,15,"Measure"),(33,40,"Categorical Dimension")]}),
("what is my Turnover across different Division ",{"entities":[(11,19,"Measure"),(37,45,"Categorical Dimension")]}),
("what is my Working Capital across different Brand ",{"entities":[(11,27,"Measure"),(44,49,"Categorical Dimension")]}),
("what is my Burn rate across different Category ",{"entities":[(11,21,"Measure"),(38,46,"Categorical Dimension")]}),
("what is my OCF across different Lines ",{"entities":[(11,14,"Measure"),(32,37,"Categorical Dimension")]}),
("what is my Operating Cash Flow across different Store ",{"entities":[(11,30,"Measure"),(48,53,"Categorical Dimension")]}),
("what is my EBIT% across different store name ",{"entities":[(11,16,"Measure"),(34,44,"Categorical Dimension")]}),
("what is my EBITDA% across different Zones ",{"entities":[(11,18,"Measure"),(36,41,"Categorical Dimension")]}),
("what is my Operating Profit% across different Block ",{"entities":[(11,28,"Measure"),(46,51,"Categorical Dimension")]}),
("what is my GM% across different Region ",{"entities":[(11,14,"Measure"),(32,38,"Categorical Dimension")]}),
("what is my Gross Margin% across different State ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my Profit Margin% across different City ",{"entities":[(11,25,"Measure"),(43,47,"Categorical Dimension")]}),
("what is my Profit% across different Country ",{"entities":[(11,18,"Measure"),(36,43,"Categorical Dimension")]}),
("what is my Profit across different Location ",{"entities":[(11,17,"Measure"),(35,43,"Categorical Dimension")]}),
("what is my Loss% across different length of service slabs ",{"entities":[(11,16,"Measure"),(34,57,"Categorical Dimension")]}),
("what is my Loss across different employee performance ",{"entities":[(11,15,"Measure"),(33,53,"Categorical Dimension")]}),
("what is my Tax across different source ",{"entities":[(11,14,"Measure"),(32,38,"Categorical Dimension")]}),
("what is my Interest rate across different business unit ",{"entities":[(11,24,"Measure"),(42,55,"Categorical Dimension")]}),
("what is my Exceptionals across different zone ",{"entities":[(11,23,"Measure"),(41,45,"Categorical Dimension")]}),
("what is my Monitoring costs across different gender ",{"entities":[(11,27,"Measure"),(45,51,"Categorical Dimension")]}),
("what is my Direct Cost across different years of service ",{"entities":[(11,23,"Measure"),(40,56,"Categorical Dimension")]}),
("what is my Depreciation across different position ",{"entities":[(11,23,"Measure"),(41,49,"Categorical Dimension")]}),
("what is my Other income across different department ",{"entities":[(11,23,"Measure"),(41,51,"Categorical Dimension")]}),
("what is my EBIT across different hierarchy ",{"entities":[(10,15,"Measure"),(33,42,"Categorical Dimension")]}),
("what is my Operating Income across different location ",{"entities":[(11,27,"Measure"),(45,53,"Categorical Dimension")]}),
("what is my Operating Profit across different division ",{"entities":[(11,27,"Measure"),(45,53,"Categorical Dimension")]}),
("what is my Cost of Sales across different service group ",{"entities":[(11,24,"Measure"),(42,55,"Categorical Dimension")]}),
("what is my vacation days across different age group ",{"entities":[(11,24,"Measure"),(42,51,"Categorical Dimension")]}),
("what is my leavers across different levels ",{"entities":[(11,18,"Measure"),(36,42,"Categorical Dimension")]}),
("what is my work tenure across different grade ",{"entities":[(11,22,"Measure"),(40,45,"Categorical Dimension")]}),
("what is my Staff training cost across different accounting_flag ",{"entities":[(11,30,"Measure"),(48,63,"Categorical Dimension")]}),
("what is my length of service across different accounting_flag ",{"entities":[(11,28,"Measure"),(46,61,"Categorical Dimension")]}),
("what is my commission across different off_region ",{"entities":[(11,21,"Measure"),(39,49,"Categorical Dimension")]}),
("what is my workplace injuries across different fund_type_ind ",{"entities":[(11,29,"Measure"),(47,60,"Categorical Dimension")]}),
("what is my referral count across different StoreResults ",{"entities":[(11,25,"Measure"),(43,55,"Categorical Dimension")]}),
("what is my number of referrals across different pending ",{"entities":[(11,30,"Measure"),(48,55,"Categorical Dimension")]}),
("what is my claims payment across different new_items ",{"entities":[(11,25,"Measure"),(43,52,"Categorical Dimension")]}),
("what is my commission payment across different Claim severity ",{"entities":[(11,29,"Measure"),(47,61,"Categorical Dimension")]}),
("what is my overtime payment across different Product Name ",{"entities":[(11,27,"Measure"),(45,57,"Categorical Dimension")]}),
("what is my churn rate across different Product type ",{"entities":[(11,21,"Measure"),(39,51,"Categorical Dimension")]}),
("what is my employee turnover across different Product category ",{"entities":[(11,28,"Measure"),(46,62,"Categorical Dimension")]}),
("what is my overtime across different Claim status ",{"entities":[(11,19,"Measure"),(37,49,"Categorical Dimension")]}),
("what is my referral incentive across different Claim type ",{"entities":[(11,29,"Measure"),(47,57,"Categorical Dimension")]}),
("what is my LOP across different Basis ",{"entities":[(11,14,"Measure"),(32,37,"Categorical Dimension")]}),
("what is my Loss of Pay across different Policy Ref ",{"entities":[(11,22,"Measure"),(40,50,"Categorical Dimension")]}),
("what is my FTE count across different Insd ",{"entities":[(11,20,"Measure"),(38,42,"Categorical Dimension")]}),
("what is my FTE vacancy count across different Risk Code Pol ",{"entities":[(11,28,"Measure"),(46,59,"Categorical Dimension")]}),
("what is my vacancy count across different Group Risk Code ",{"entities":[(10,24,"Measure"),(42,57,"Categorical Dimension")]}),
("what is my vacancy across different BPC Code ",{"entities":[(11,18,"Measure"),(36,44,"Categorical Dimension")]}),
("what is my filled vacancies across different Division ",{"entities":[(11,27,"Measure"),(45,53,"Categorical Dimension")]}),
("what is my open vacancies across different Office ",{"entities":[(11,25,"Measure"),(43,49,"Categorical Dimension")]}),
("what is my joining bonus across different Vertical ",{"entities":[(11,24,"Measure"),(42,50,"Categorical Dimension")]}),
("what is my notice period across different department ",{"entities":[(11,24,"Measure"),(42,52,"Categorical Dimension")]}),
("what is my relocation charges across different service line ",{"entities":[(11,29,"Measure"),(47,59,"Categorical Dimension")]}),
("what is my number of requisitions across different Horizontal ",{"entities":[(11,33,"Measure"),(51,61,"Categorical Dimension")]}),
("what is my number of resignations across different Vertical ",{"entities":[(11,33,"Measure"),(51,59,"Categorical Dimension")]}),
("what is my number of promotions across different Geography ",{"entities":[(11,31,"Measure"),(49,58,"Categorical Dimension")]}),
("what is my number of enrollments across different Sub-business group ",{"entities":[(11,32,"Measure"),(50,68,"Categorical Dimension")]}),
("what is my workforce tenure across different Business Group ",{"entities":[(11,27,"Measure"),(45,59,"Categorical Dimension")]}),
("what is my workforce across different Stream ",{"entities":[(11,20,"Measure"),(38,44,"Categorical Dimension")]}),
("what is my headcount across different Revenue Type ",{"entities":[(11,21,"Measure"),(38,50,"Categorical Dimension")]}),
("what is my Expected YTD across different broker ",{"entities":[(12,24,"Goal Measure"),(41,47,"Categorical Dimension")]}),
("what is my Quoted EPI across different lloyd's broker ",{"entities":[(11,21,"Goal Measure"),(39,53,"Categorical Dimension")]}),
("what is my (PY) Forecast Premium across different event ",{"entities":[(11,27,"Goal Measure"),(45,50,"Categorical Dimension")]}),
("what is my Forecast Premium across different accounting classes ",{"entities":[(11,27,"Goal Measure"),(45,63,"Categorical Dimension")]}),
("what is my Revenue Target across different Claim severity ",{"entities":[(11,25,"Goal Measure"),(43,57,"Categorical Dimension")]}),
("what is my Overheads Budget across different policy holder ",{"entities":[(11,27,"Goal Measure"),(45,58,"Categorical Dimension")]}),
("what is my EBITDA Budget across different policy type ",{"entities":[(11,24,"Goal Measure"),(42,53,"Categorical Dimension")]}),
("what is my Revenue Budget across different policy ",{"entities":[(11,25,"Goal Measure"),(43,49,"Categorical Dimension")]}),
("what is my target headcount across different Product Name ",{"entities":[(11,27,"Goal Measure"),(45,57,"Categorical Dimension")]}),
("Please plot mtd_sales vs Order status ",{"entities":[(12,21,"Measure"),(25,37,"Categorical Dimension")]}),
("Please plot mtd_redem_afb vs Status ",{"entities":[(12,25,"Measure"),(29,35,"Categorical Dimension")]}),
("Please plot mtd_redem vs Size ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot mtd_percent vs Type ",{"entities":[(12,23,"Measure"),(27,31,"Categorical Dimension")]}),
("Please plot mtd_net_flow vs Quality ",{"entities":[(12,24,"Measure"),(28,35,"Categorical Dimension")]}),
("Please plot mtd_net vs Grade ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot MTD% vs Class ",{"entities":[(12,16,"Measure"),(20,25,"Categorical Dimension")]}),
("Please plot mtd vs Mode ",{"entities":[(12,15,"Measure"),(19,23,"Categorical Dimension")]}),
("Please plot YTDNetSales vs Method ",{"entities":[(12,23,"Measure"),(27,33,"Categorical Dimension")]}),
("Please plot ytd_sales_afb vs Channel ",{"entities":[(12,25,"Measure"),(29,36,"Categorical Dimension")]}),
("Please plot ytd_sales vs Item ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot ytd_redem_afb vs Department ",{"entities":[(12,26,"Measure"),(29,39,"Categorical Dimension")]}),
("Please plot ytd_redem vs order type ",{"entities":[(12,21,"Measure"),(25,35,"Categorical Dimension")]}),
("Please plot ytd_percent vs Section ",{"entities":[(12,23,"Measure"),(27,34,"Categorical Dimension")]}),
("Please plot ytd_net_flow vs Division ",{"entities":[(12,24,"Measure"),(28,36,"Categorical Dimension")]}),
("Please plot ytd_net vs Brand ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot YTD% vs Category ",{"entities":[(12,16,"Measure"),(20,28,"Categorical Dimension")]}),
("Please plot ytd vs Lines ",{"entities":[(12,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Please plot usd_amt vs Store ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot total_sales_afb vs store name ",{"entities":[(12,27,"Measure"),(31,41,"Categorical Dimension")]}),
("Please plot total_sales vs Zones ",{"entities":[(12,23,"Measure"),(27,32,"Categorical Dimension")]}),
("Please plot total_redem_afb vs Block ",{"entities":[(12,27,"Measure"),(31,36,"Categorical Dimension")]}),
("Please plot total_redem vs Region ",{"entities":[(12,23,"Measure"),(27,33,"Categorical Dimension")]}),
("Please plot total_pending vs State ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot today_sales_afb vs City ",{"entities":[(12,27,"Measure"),(31,35,"Categorical Dimension")]}),
("Please plot today_sales vs Country ",{"entities":[(12,23,"Measure"),(27,34,"Categorical Dimension")]}),
("Please plot today_redem_afb vs Location ",{"entities":[(12,27,"Measure"),(31,39,"Categorical Dimension")]}),
("Please plot today_redem vs length of service slabs ",{"entities":[(12,23,"Measure"),(27,50,"Categorical Dimension")]}),
("Please plot today_net_flow vs employee performance ",{"entities":[(12,26,"Measure"),(30,50,"Categorical Dimension")]}),
("Please plot today_net vs source ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot today vs business unit ",{"entities":[(12,17,"Measure"),(21,34,"Categorical Dimension")]}),
("Please plot sales_afb vs zone ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot sales vs gender ",{"entities":[(12,17,"Measure"),(21,27,"Categorical Dimension")]}),
("Please plot redemptions_afb vs years of service ",{"entities":[(12,27,"Measure"),(31,47,"Categorical Dimension")]}),
("Please plot redemptions vs position ",{"entities":[(12,23,"Measure"),(27,35,"Categorical Dimension")]}),
("Please plot QTDNetSales vs department ",{"entities":[(12,23,"Measure"),(26,37,"Categorical Dimension")]}),
("Please plot qtd_sales vs hierarchy ",{"entities":[(12,21,"Measure"),(25,34,"Categorical Dimension")]}),
("Please plot qtd_redem vs location ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot pyr_redem vs division ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot pyr_net vs service group ",{"entities":[(12,19,"Measure"),(23,36,"Categorical Dimension")]}),
("Please plot avg policy size vs age group ",{"entities":[(12,27,"Measure"),(31,40,"Categorical Dimension")]}),
("Please plot underwriting speed vs levels ",{"entities":[(12,30,"Measure"),(34,40,"Categorical Dimension")]}),
("Please plot cost per claim vs grade ",{"entities":[(12,26,"Measure"),(29,35,"Categorical Dimension")]}),
("Please plot number of referrals vs accounting_flag ",{"entities":[(12,31,"Measure"),(35,50,"Categorical Dimension")]}),
("Please plot Premium vs accounting_flag ",{"entities":[(12,19,"Measure"),(23,38,"Categorical Dimension")]}),
("Please plot Payout vs off_region ",{"entities":[(12,18,"Measure"),(22,32,"Categorical Dimension")]}),
("Please plot Submitted EPI vs fund_type_ind ",{"entities":[(12,25,"Measure"),(29,42,"Categorical Dimension")]}),
("Please plot Actual EPI YTD vs StoreResults ",{"entities":[(12,26,"Measure"),(30,42,"Categorical Dimension")]}),
("Please plot time to settle a claim vs pending ",{"entities":[(12,34,"Measure"),(38,45,"Categorical Dimension")]}),
("Please plot Budget Premium vs new_items ",{"entities":[(12,26,"Measure"),(30,39,"Categorical Dimension")]}),
("Please plot PY Actual YTD vs Claim severity ",{"entities":[(12,25,"Measure"),(29,43,"Categorical Dimension")]}),
("Please plot Policy Count vs Product Name ",{"entities":[(12,25,"Measure"),(28,40,"Categorical Dimension")]}),
("Please plot Limit Remaining vs Product type ",{"entities":[(12,27,"Measure"),(31,43,"Categorical Dimension")]}),
("Please plot Plan Remaining vs Product category ",{"entities":[(12,26,"Measure"),(30,46,"Categorical Dimension")]}),
("Please plot Plan Remaining % vs Claim status ",{"entities":[(12,28,"Measure"),(32,44,"Categorical Dimension")]}),
("Please plot Claim Movement vs Claim type ",{"entities":[(12,26,"Measure"),(30,40,"Categorical Dimension")]}),
("Please plot Expiring EPI vs Basis ",{"entities":[(12,24,"Measure"),(28,33,"Categorical Dimension")]}),
("Please plot Lost / Lapsed EPI vs Policy Ref ",{"entities":[(12,29,"Measure"),(33,43,"Categorical Dimension")]}),
("Please plot Lapsed EPI vs Insd ",{"entities":[(12,22,"Measure"),(26,30,"Categorical Dimension")]}),
("Please plot Declinature & NTU EPI vs Risk Code Pol ",{"entities":[(12,33,"Measure"),(37,50,"Categorical Dimension")]}),
("Please plot Bound Premium vs Group Risk Code ",{"entities":[(12,25,"Measure"),(29,44,"Categorical Dimension")]}),
("Please plot Var % YoY vs BPC Code ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot Var Plan Used % vs Division ",{"entities":[(12,27,"Measure"),(31,39,"Categorical Dimension")]}),
("Please plot Benchmark Adequacy vs Office ",{"entities":[(12,30,"Measure"),(34,40,"Categorical Dimension")]}),
("Please plot Tech Adequacy vs Vertical ",{"entities":[(12,25,"Measure"),(29,37,"Categorical Dimension")]}),
("Please plot Attrition / Attr GILR vs department ",{"entities":[(12,33,"Measure"),(37,47,"Categorical Dimension")]}),
("Please plot Loss Ratio / GILR vs service line ",{"entities":[(12,29,"Measure"),(33,45,"Categorical Dimension")]}),
("Please plot Yet to Renew vs Horizontal ",{"entities":[(12,24,"Measure"),(28,38,"Categorical Dimension")]}),
("Please plot Prior Yr YTD vs Vertical ",{"entities":[(13,25,"Measure"),(28,36,"Categorical Dimension")]}),
("Please plot Actual YTD vs Geography ",{"entities":[(13,23,"Measure"),(26,35,"Categorical Dimension")]}),
("Please plot Prior Yr YOY vs Sub-business group ",{"entities":[(12,24,"Measure"),(28,46,"Categorical Dimension")]}),
("Please plot Variance to Prior Year vs Business Group ",{"entities":[(13,35,"Measure"),(38,52,"Categorical Dimension")]}),
("Please plot Renewal % vs Stream ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot New % vs Revenue Type ",{"entities":[(12,17,"Measure"),(21,33,"Categorical Dimension")]}),
("Please plot Rate Chg % vs portfolio ",{"entities":[(12,22,"Measure"),(26,35,"Categorical Dimension")]}),
("Please plot Retention % vs client ",{"entities":[(12,23,"Measure"),(27,33,"Categorical Dimension")]}),
("Please plot Bound Premium vs risk group ",{"entities":[(12,25,"Measure"),(29,39,"Categorical Dimension")]}),
("Please plot Overheads vs broker ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot EBITDA vs lloyd's broker ",{"entities":[(12,18,"Measure"),(22,36,"Categorical Dimension")]}),
("Please plot Revenue per day vs event ",{"entities":[(12,27,"Measure"),(31,36,"Categorical Dimension")]}),
("Please plot Net Profit Margin vs accounting classes ",{"entities":[(12,29,"Measure"),(33,51,"Categorical Dimension")]}),
("Please plot GM vs Claim severity ",{"entities":[(12,14,"Measure"),(18,32,"Categorical Dimension")]}),
("Please plot Gross Margin vs policy holder ",{"entities":[(12,24,"Measure"),(28,41,"Categorical Dimension")]}),
("Please plot Expense vs policy type ",{"entities":[(12,19,"Measure"),(23,34,"Categorical Dimension")]}),
("Please plot Revenue vs policy ",{"entities":[(12,19,"Measure"),(23,29,"Categorical Dimension")]}),
("Please plot Growth% vs Product Name ",{"entities":[(12,19,"Measure"),(23,35,"Categorical Dimension")]}),
("Please plot attrition rate vs Product class ",{"entities":[(12,26,"Measure"),(30,43,"Categorical Dimension")]}),
("Please plot layover vs Product type ",{"entities":[(12,19,"Measure"),(23,35,"Categorical Dimension")]}),
("Please plot retention rate vs Product category ",{"entities":[(12,26,"Measure"),(30,46,"Categorical Dimension")]}),
("Please plot training period vs Carrier ",{"entities":[(12,27,"Measure"),(31,38,"Categorical Dimension")]}),
("Please plot ctc vs managing agent ",{"entities":[(12,15,"Measure"),(19,33,"Categorical Dimension")]}),
("Please plot time to fill vs agent ",{"entities":[(12,24,"Measure"),(28,33,"Categorical Dimension")]}),
("Please plot number of hires vs Claim status ",{"entities":[(12,27,"Measure"),(31,43,"Categorical Dimension")]}),
("Please plot number of recruitments vs Claim type ",{"entities":[(12,34,"Measure"),(38,48,"Categorical Dimension")]}),
("Please plot recruitment cost vs Age group ",{"entities":[(12,28,"Measure"),(32,41,"Categorical Dimension")]}),
("Please plot training days vs Group ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot training cost vs cohort ",{"entities":[(12,25,"Measure"),(29,35,"Categorical Dimension")]}),
("Please plot variable pay vs Order status ",{"entities":[(12,24,"Measure"),(28,40,"Categorical Dimension")]}),
("Please plot fixed pay vs Status ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot bonus vs Size ",{"entities":[(12,17,"Measure"),(21,25,"Categorical Dimension")]}),
("Please plot working hours vs Type ",{"entities":[(12,25,"Measure"),(29,33,"Categorical Dimension")]}),
("Please plot experience vs Quality ",{"entities":[(12,22,"Measure"),(26,33,"Categorical Dimension")]}),
("Please plot Sick leaves vs Grade ",{"entities":[(12,23,"Measure"),(27,32,"Categorical Dimension")]}),
("Please plot earned leaves vs Class ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot salary vs Mode ",{"entities":[(12,18,"Measure"),(22,26,"Categorical Dimension")]}),
("Please plot number of employees vs Method ",{"entities":[(12,31,"Measure"),(35,41,"Categorical Dimension")]}),
("Please plot dividend rate vs Channel ",{"entities":[(12,25,"Measure"),(29,36,"Categorical Dimension")]}),
("Please plot dividend vs Item ",{"entities":[(12,20,"Measure"),(24,28,"Categorical Dimension")]}),
("Please plot D/E Ratio vs Department ",{"entities":[(12,21,"Measure"),(25,35,"Categorical Dimension")]}),
("Please plot CAPEX vs order type ",{"entities":[(12,17,"Measure"),(21,31,"Categorical Dimension")]}),
("Please plot OPEX vs Section ",{"entities":[(12,16,"Measure"),(20,27,"Categorical Dimension")]}),
("Please plot Turnover vs Division ",{"entities":[(12,20,"Measure"),(24,32,"Categorical Dimension")]}),
("Please plot Working Capital vs Brand ",{"entities":[(12,27,"Measure"),(31,36,"Categorical Dimension")]}),
("Please plot Burn rate vs Category ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot OCF vs Lines ",{"entities":[(12,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Please plot Operating Cash Flow vs Store ",{"entities":[(12,31,"Measure"),(35,40,"Categorical Dimension")]}),
("Please plot EBIT% vs store name ",{"entities":[(12,17,"Measure"),(21,31,"Categorical Dimension")]}),
("Please plot EBITDA% vs Zones ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot Operating Profit% vs Block ",{"entities":[(12,29,"Measure"),(33,38,"Categorical Dimension")]}),
("Please plot GM% vs Region ",{"entities":[(12,15,"Measure"),(19,25,"Categorical Dimension")]}),
("Please plot Gross Margin% vs State ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot Profit Margin% vs City ",{"entities":[(12,26,"Measure"),(30,34,"Categorical Dimension")]}),
("Please plot Profit% vs Country ",{"entities":[(12,19,"Measure"),(23,30,"Categorical Dimension")]}),
("Please plot Profit vs Location ",{"entities":[(12,18,"Measure"),(22,30,"Categorical Dimension")]}),
("Please plot Loss% vs length of service slabs ",{"entities":[(12,17,"Measure"),(21,44,"Categorical Dimension")]}),
("Please plot Loss vs employee performance ",{"entities":[(12,16,"Measure"),(20,40,"Categorical Dimension")]}),
("Please plot Tax vs source ",{"entities":[(12,15,"Measure"),(19,25,"Categorical Dimension")]}),
("Please plot Interest rate vs business unit ",{"entities":[(12,25,"Measure"),(29,42,"Categorical Dimension")]}),
("Please plot Exceptionals vs zone ",{"entities":[(12,24,"Measure"),(28,32,"Categorical Dimension")]}),
("Please plot Monitoring costs vs gender ",{"entities":[(12,28,"Measure"),(32,38,"Categorical Dimension")]}),
("Please plot Direct Cost vs years of service ",{"entities":[(12,23,"Measure"),(27,43,"Categorical Dimension")]}),
("Please plot Depreciation vs position ",{"entities":[(12,24,"Measure"),(28,36,"Categorical Dimension")]}),
("Please plot Other income vs department ",{"entities":[(12,24,"Measure"),(28,38,"Categorical Dimension")]}),
("Please plot EBIT vs hierarchy ",{"entities":[(12,16,"Measure"),(20,29,"Categorical Dimension")]}),
("Please plot Operating Income vs location ",{"entities":[(12,28,"Measure"),(32,40,"Categorical Dimension")]}),
("Please plot Operating Profit vs division ",{"entities":[(12,28,"Measure"),(32,40,"Categorical Dimension")]}),
("Please plot Cost of Sales vs service group ",{"entities":[(12,25,"Measure"),(29,42,"Categorical Dimension")]}),
("Please plot vacation days vs age group ",{"entities":[(12,25,"Measure"),(29,38,"Categorical Dimension")]}),
("Please plot leavers vs levels ",{"entities":[(12,19,"Measure"),(23,29,"Categorical Dimension")]}),
("Please plot work tenure vs grade ",{"entities":[(12,23,"Measure"),(27,32,"Categorical Dimension")]}),
("Please plot Staff training cost vs accounting_flag ",{"entities":[(12,31,"Measure"),(35,50,"Categorical Dimension")]}),
("Please plot length of service vs accounting_flag ",{"entities":[(12,29,"Measure"),(33,48,"Categorical Dimension")]}),
("Please plot commission vs off_region ",{"entities":[(12,22,"Measure"),(26,36,"Categorical Dimension")]}),
("Please plot workplace injuries vs fund_type_ind ",{"entities":[(12,30,"Measure"),(34,47,"Categorical Dimension")]}),
("Please plot referral count vs StoreResults ",{"entities":[(12,26,"Measure"),(30,42,"Categorical Dimension")]}),
("Please plot number of referrals vs pending ",{"entities":[(12,31,"Measure"),(35,42,"Categorical Dimension")]}),
("Please plot claims payment vs new_items ",{"entities":[(12,26,"Measure"),(30,39,"Categorical Dimension")]}),
("Please plot commission payment vs Claim severity ",{"entities":[(12,30,"Measure"),(34,48,"Categorical Dimension")]}),
("Please plot overtime payment vs Product Name ",{"entities":[(12,28,"Measure"),(32,44,"Categorical Dimension")]}),
("Please plot churn rate vs Product type ",{"entities":[(12,22,"Measure"),(26,38,"Categorical Dimension")]}),
("Please plot employee turnover vs Product category ",{"entities":[(12,29,"Measure"),(33,49,"Categorical Dimension")]}),
("Please plot overtime vs Claim status ",{"entities":[(12,20,"Measure"),(24,36,"Categorical Dimension")]}),
("Please plot referral incentive vs Claim type ",{"entities":[(12,30,"Measure"),(34,44,"Categorical Dimension")]}),
("Please plot LOP vs Basis ",{"entities":[(12,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Please plot Loss of Pay vs Policy Ref ",{"entities":[(12,23,"Measure"),(27,37,"Categorical Dimension")]}),
("Please plot FTE count vs Insd ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot FTE vacancy count vs Risk Code Pol ",{"entities":[(12,29,"Measure"),(33,46,"Categorical Dimension")]}),
("Please plot vacancy count vs Group Risk Code ",{"entities":[(12,25,"Measure"),(29,44,"Categorical Dimension")]}),
("Please plot vacancy vs BPC Code ",{"entities":[(12,19,"Measure"),(23,31,"Categorical Dimension")]}),
("Please plot filled vacancies vs Division ",{"entities":[(12,28,"Measure"),(32,40,"Categorical Dimension")]}),
("Please plot open vacancies vs Office ",{"entities":[(12,26,"Measure"),(30,36,"Categorical Dimension")]}),
("Please plot joining bonus vs Vertical ",{"entities":[(12,25,"Measure"),(29,37,"Categorical Dimension")]}),
("Please plot notice period vs department ",{"entities":[(12,25,"Measure"),(29,39,"Categorical Dimension")]}),
("Please plot relocation charges vs service line ",{"entities":[(12,30,"Measure"),(34,46,"Categorical Dimension")]}),
("Please plot number of requisitions vs Horizontal ",{"entities":[(12,34,"Measure"),(38,48,"Categorical Dimension")]}),
("Please plot number of resignations vs Vertical ",{"entities":[(12,34,"Measure"),(38,46,"Categorical Dimension")]}),
("Please plot number of promotions vs Geography ",{"entities":[(12,32,"Measure"),(36,45,"Categorical Dimension")]}),
("Please plot number of enrollments vs Sub-business group ",{"entities":[(12,33,"Measure"),(37,55,"Categorical Dimension")]}),
("Please plot workforce tenure vs Business Group ",{"entities":[(12,28,"Measure"),(32,46,"Categorical Dimension")]}),
("Please plot workforce vs Stream ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot headcount vs Revenue Type ",{"entities":[(12,21,"Measure"),(25,37,"Categorical Dimension")]}),
("Please plot completed_mtd vs Product class",{"entities":[(12,25,"Measure"),(29,42,"Categorical Dimension")]}),
("Please plot completed_items vs Product type ",{"entities":[(12,27,"Measure"),(31,43,"Categorical Dimension")]}),
("Please plot AUM vs Product category ",{"entities":[(12,15,"Measure"),(19,35,"Categorical Dimension")]}),
("Please plot AsOf_sales vs Carrier ",{"entities":[(12,23,"Measure"),(26,33,"Categorical Dimension")]}),
("Please plot net_ytd vs managing agent ",{"entities":[(12,19,"Measure"),(23,37,"Categorical Dimension")]}),
("Please plot net_today vs agent ",{"entities":[(12,21,"Measure"),(25,30,"Categorical Dimension")]}),
("Please plot Net_Sales vs Claim status ",{"entities":[(12,21,"Measure"),(25,37,"Categorical Dimension")]}),
("Please plot net_mtd vs Claim type ",{"entities":[(12,19,"Measure"),(23,33,"Categorical Dimension")]}),
("Please plot Net_AFB vs Age group ",{"entities":[(12,19,"Measure"),(23,32,"Categorical Dimension")]}),
("Please plot MTDNetSales vs Group ",{"entities":[(12,23,"Measure"),(27,32,"Categorical Dimension")]}),
("Please plot mtd_sales_afb vs cohort ",{"entities":[(12,25,"Measure"),(29,35,"Categorical Dimension")]}),
("Please plot mtd_sales vs Order status ",{"entities":[(12,21,"Measure"),(25,37,"Categorical Dimension")]}),
("Please plot mtd_redem_afb vs Status ",{"entities":[(12,25,"Measure"),(29,35,"Categorical Dimension")]}),
("Please plot mtd_redem vs Size ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot mtd_percent vs Type ",{"entities":[(12,23,"Measure"),(27,31,"Categorical Dimension")]}),
("Please plot mtd_net_flow vs Quality ",{"entities":[(12,24,"Measure"),(28,35,"Categorical Dimension")]}),
("Please plot mtd_net vs Grade ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot MTD% vs Class ",{"entities":[(12,16,"Measure"),(20,25,"Categorical Dimension")]}),
("Please plot mtd vs Mode ",{"entities":[(12,15,"Measure"),(19,23,"Categorical Dimension")]}),
("Please plot YTDNetSales vs Method ",{"entities":[(12,23,"Measure"),(27,33,"Categorical Dimension")]}),
("Please plot ytd_sales_afb vs Channel ",{"entities":[(12,25,"Measure"),(29,36,"Categorical Dimension")]}),
("Please plot ytd_sales vs Item ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot ytd_redem_afb vs Department ",{"entities":[(12,26,"Measure"),(29,39,"Categorical Dimension")]}),
("Please plot ytd_redem vs order type ",{"entities":[(12,21,"Measure"),(25,35,"Categorical Dimension")]}),
("Please plot ytd_percent vs Section ",{"entities":[(12,23,"Measure"),(27,34,"Categorical Dimension")]}),
("Please plot ytd_net_flow vs Division ",{"entities":[(12,24,"Measure"),(28,36,"Categorical Dimension")]}),
("Please plot ytd_net vs Brand ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot YTD% vs Category ",{"entities":[(12,16,"Measure"),(20,28,"Categorical Dimension")]}),
("Please plot ytd vs Lines ",{"entities":[(12,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Please plot usd_amt vs Store ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot total_sales_afb vs store name ",{"entities":[(12,27,"Measure"),(31,41,"Categorical Dimension")]}),
("Please plot total_sales vs Zones ",{"entities":[(12,23,"Measure"),(27,32,"Categorical Dimension")]}),
("Please plot total_redem_afb vs Block ",{"entities":[(12,27,"Measure"),(31,36,"Categorical Dimension")]}),
("Please plot total_redem vs Region ",{"entities":[(12,23,"Measure"),(27,33,"Categorical Dimension")]}),
("Please plot total_pending vs State ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot today_sales_afb vs City ",{"entities":[(12,27,"Measure"),(31,35,"Categorical Dimension")]}),
("Please plot today_sales vs Country ",{"entities":[(12,23,"Measure"),(27,34,"Categorical Dimension")]}),
("Please plot today_redem_afb vs Location ",{"entities":[(12,27,"Measure"),(31,39,"Categorical Dimension")]}),
("Please plot today_redem vs length of service slabs ",{"entities":[(12,23,"Measure"),(27,50,"Categorical Dimension")]}),
("Please plot today_net_flow vs employee performance ",{"entities":[(12,26,"Measure"),(30,50,"Categorical Dimension")]}),
("Please plot today_net vs source ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot today vs business unit ",{"entities":[(12,17,"Measure"),(21,34,"Categorical Dimension")]}),
("Please plot sales_afb vs zone ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot sales vs gender ",{"entities":[(12,17,"Measure"),(21,27,"Categorical Dimension")]}),
("Please plot redemptions_afb vs years of service ",{"entities":[(12,27,"Measure"),(31,47,"Categorical Dimension")]}),
("Please plot redemptions vs position ",{"entities":[(12,23,"Measure"),(27,35,"Categorical Dimension")]}),
("Please plot QTDNetSales vs department ",{"entities":[(12,23,"Measure"),(26,37,"Categorical Dimension")]}),
("Please plot qtd_sales vs hierarchy ",{"entities":[(12,21,"Measure"),(25,34,"Categorical Dimension")]}),
("Please plot qtd_redem vs location ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot pyr_redem vs division ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot pyr_net vs service group ",{"entities":[(12,19,"Measure"),(23,36,"Categorical Dimension")]}),
("Please plot avg policy size vs age group ",{"entities":[(12,27,"Measure"),(31,40,"Categorical Dimension")]}),
("Please plot underwriting speed vs levels ",{"entities":[(12,30,"Measure"),(34,40,"Categorical Dimension")]}),
("Please plot cost per claim vs grade ",{"entities":[(12,26,"Measure"),(29,35,"Categorical Dimension")]}),
("Please plot number of referrals vs accounting_flag ",{"entities":[(12,31,"Measure"),(35,50,"Categorical Dimension")]}),
("Please plot Premium vs accounting_flag ",{"entities":[(12,19,"Measure"),(23,38,"Categorical Dimension")]}),
("Please plot Payout vs off_region ",{"entities":[(12,18,"Measure"),(22,32,"Categorical Dimension")]}),
("Please plot Submitted EPI vs fund_type_ind ",{"entities":[(12,25,"Measure"),(29,42,"Categorical Dimension")]}),
("Please plot Actual EPI YTD vs StoreResults ",{"entities":[(12,26,"Measure"),(30,42,"Categorical Dimension")]}),
("Please plot time to settle a claim vs pending ",{"entities":[(12,34,"Measure"),(38,45,"Categorical Dimension")]}),
("Please plot Budget Premium vs new_items ",{"entities":[(12,26,"Measure"),(30,39,"Categorical Dimension")]}),
("Please plot PY Actual YTD vs Claim severity ",{"entities":[(12,25,"Measure"),(29,43,"Categorical Dimension")]}),
("Please plot Policy Count vs Product Name ",{"entities":[(12,25,"Measure"),(28,40,"Categorical Dimension")]}),
("Please plot Limit Remaining vs Product type ",{"entities":[(12,27,"Measure"),(31,43,"Categorical Dimension")]}),
("Please plot Plan Remaining vs Product category ",{"entities":[(12,26,"Measure"),(30,46,"Categorical Dimension")]}),
("Please plot Plan Remaining % vs Claim status ",{"entities":[(12,28,"Measure"),(32,44,"Categorical Dimension")]}),
("Please plot Claim Movement vs Claim type ",{"entities":[(12,26,"Measure"),(30,40,"Categorical Dimension")]}),
("Please plot Expiring EPI vs Basis ",{"entities":[(12,24,"Measure"),(28,33,"Categorical Dimension")]}),
("Please plot Lost / Lapsed EPI vs Policy Ref ",{"entities":[(12,29,"Measure"),(33,43,"Categorical Dimension")]}),
("Please plot Lapsed EPI vs Insd ",{"entities":[(12,22,"Measure"),(26,30,"Categorical Dimension")]}),
("Please plot Declinature & NTU EPI vs Risk Code Pol ",{"entities":[(12,33,"Measure"),(37,50,"Categorical Dimension")]}),
("Please plot Bound Premium vs Group Risk Code ",{"entities":[(12,25,"Measure"),(29,44,"Categorical Dimension")]}),
("Please plot Var % YoY vs BPC Code ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot Var Plan Used % vs Division ",{"entities":[(12,27,"Measure"),(31,39,"Categorical Dimension")]}),
("Please plot Benchmark Adequacy vs Office ",{"entities":[(12,30,"Measure"),(34,40,"Categorical Dimension")]}),
("Please plot Tech Adequacy vs Vertical ",{"entities":[(12,25,"Measure"),(29,37,"Categorical Dimension")]}),
("Please plot Attrition / Attr GILR vs department ",{"entities":[(12,33,"Measure"),(37,47,"Categorical Dimension")]}),
("Please plot Loss Ratio / GILR vs service line ",{"entities":[(12,29,"Measure"),(33,45,"Categorical Dimension")]}),
("Please plot Yet to Renew vs Horizontal ",{"entities":[(12,24,"Measure"),(28,38,"Categorical Dimension")]}),
("Please plot Prior Yr YTD vs Vertical ",{"entities":[(13,25,"Measure"),(28,36,"Categorical Dimension")]}),
("Please plot Actual YTD vs Geography ",{"entities":[(13,23,"Measure"),(26,35,"Categorical Dimension")]}),
("Please plot Prior Yr YOY vs Sub-business group ",{"entities":[(12,24,"Measure"),(28,46,"Categorical Dimension")]}),
("Please plot Variance to Prior Year vs Business Group ",{"entities":[(13,35,"Measure"),(38,52,"Categorical Dimension")]}),
("Please plot Renewal % vs Stream ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot New % vs Revenue Type ",{"entities":[(12,17,"Measure"),(21,33,"Categorical Dimension")]}),
("Please plot Rate Chg % vs portfolio ",{"entities":[(12,22,"Measure"),(26,35,"Categorical Dimension")]}),
("Please plot Retention % vs client ",{"entities":[(12,23,"Measure"),(27,33,"Categorical Dimension")]}),
("Please plot Bound Premium vs risk group ",{"entities":[(12,25,"Measure"),(29,39,"Categorical Dimension")]}),
("Please plot Overheads vs broker ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot EBITDA vs lloyd's broker ",{"entities":[(12,18,"Measure"),(22,36,"Categorical Dimension")]}),
("Please plot Revenue per day vs event ",{"entities":[(12,27,"Measure"),(31,36,"Categorical Dimension")]}),
("Please plot Net Profit Margin vs accounting classes ",{"entities":[(12,29,"Measure"),(33,51,"Categorical Dimension")]}),
("Please plot GM vs Claim severity ",{"entities":[(12,14,"Measure"),(18,32,"Categorical Dimension")]}),
("Please plot Gross Margin vs policy holder ",{"entities":[(12,24,"Measure"),(28,41,"Categorical Dimension")]}),
("Please plot Expense vs policy type ",{"entities":[(12,19,"Measure"),(23,34,"Categorical Dimension")]}),
("Please plot Revenue vs policy ",{"entities":[(12,19,"Measure"),(23,29,"Categorical Dimension")]}),
("Please plot Growth% vs Product Name ",{"entities":[(12,19,"Measure"),(23,35,"Categorical Dimension")]}),
("Please plot attrition rate vs Product class ",{"entities":[(12,26,"Measure"),(30,43,"Categorical Dimension")]}),
("Please plot layover vs Product type ",{"entities":[(12,19,"Measure"),(23,35,"Categorical Dimension")]}),
("Please plot retention rate vs Product category ",{"entities":[(12,26,"Measure"),(30,46,"Categorical Dimension")]}),
("Please plot training period vs Carrier ",{"entities":[(12,27,"Measure"),(31,38,"Categorical Dimension")]}),
("Please plot ctc vs managing agent ",{"entities":[(12,15,"Measure"),(19,33,"Categorical Dimension")]}),
("Please plot time to fill vs agent ",{"entities":[(12,24,"Measure"),(28,33,"Categorical Dimension")]}),
("Please plot number of hires vs Claim status ",{"entities":[(12,27,"Measure"),(31,43,"Categorical Dimension")]}),
("Please plot number of recruitments vs Claim type ",{"entities":[(12,34,"Measure"),(38,48,"Categorical Dimension")]}),
("Please plot recruitment cost vs Age group ",{"entities":[(12,28,"Measure"),(32,41,"Categorical Dimension")]}),
("Please plot training days vs Group ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot training cost vs cohort ",{"entities":[(12,25,"Measure"),(29,35,"Categorical Dimension")]}),
("Please plot variable pay vs Order status ",{"entities":[(12,24,"Measure"),(28,40,"Categorical Dimension")]}),
("Please plot fixed pay vs Status ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot bonus vs Size ",{"entities":[(12,17,"Measure"),(21,25,"Categorical Dimension")]}),
("Please plot working hours vs Type ",{"entities":[(12,25,"Measure"),(29,33,"Categorical Dimension")]}),
("Please plot experience vs Quality ",{"entities":[(12,22,"Measure"),(26,33,"Categorical Dimension")]}),
("Please plot Sick leaves vs Grade ",{"entities":[(12,23,"Measure"),(27,32,"Categorical Dimension")]}),
("Please plot earned leaves vs Class ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot salary vs Mode ",{"entities":[(12,18,"Measure"),(22,26,"Categorical Dimension")]}),
("Please plot number of employees vs Method ",{"entities":[(12,31,"Measure"),(35,41,"Categorical Dimension")]}),
("Please plot dividend rate vs Channel ",{"entities":[(12,25,"Measure"),(29,36,"Categorical Dimension")]}),
("Please plot dividend vs Item ",{"entities":[(12,20,"Measure"),(24,28,"Categorical Dimension")]}),
("Please plot D/E Ratio vs Department ",{"entities":[(12,21,"Measure"),(25,35,"Categorical Dimension")]}),
("Please plot CAPEX vs order type ",{"entities":[(12,17,"Measure"),(21,31,"Categorical Dimension")]}),
("Please plot OPEX vs Section ",{"entities":[(12,16,"Measure"),(20,27,"Categorical Dimension")]}),
("Please plot Turnover vs Division ",{"entities":[(12,20,"Measure"),(24,32,"Categorical Dimension")]}),
("Please plot Working Capital vs Brand ",{"entities":[(12,27,"Measure"),(31,36,"Categorical Dimension")]}),
("Please plot Burn rate vs Category ",{"entities":[(12,21,"Measure"),(25,33,"Categorical Dimension")]}),
("Please plot OCF vs Lines ",{"entities":[(12,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Please plot Operating Cash Flow vs Store ",{"entities":[(12,31,"Measure"),(35,40,"Categorical Dimension")]}),
("Please plot EBIT% vs store name ",{"entities":[(12,17,"Measure"),(21,31,"Categorical Dimension")]}),
("Please plot EBITDA% vs Zones ",{"entities":[(12,19,"Measure"),(23,28,"Categorical Dimension")]}),
("Please plot Operating Profit% vs Block ",{"entities":[(12,29,"Measure"),(33,38,"Categorical Dimension")]}),
("Please plot GM% vs Region ",{"entities":[(12,15,"Measure"),(19,25,"Categorical Dimension")]}),
("Please plot Gross Margin% vs State ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot Profit Margin% vs City ",{"entities":[(12,26,"Measure"),(30,34,"Categorical Dimension")]}),
("Please plot Profit% vs Country ",{"entities":[(12,19,"Measure"),(23,30,"Categorical Dimension")]}),
("Please plot Profit vs Location ",{"entities":[(12,18,"Measure"),(22,30,"Categorical Dimension")]}),
("Please plot Loss% vs length of service slabs ",{"entities":[(12,17,"Measure"),(21,44,"Categorical Dimension")]}),
("Please plot Loss vs employee performance ",{"entities":[(12,16,"Measure"),(20,40,"Categorical Dimension")]}),
("Please plot Tax vs source ",{"entities":[(12,15,"Measure"),(19,25,"Categorical Dimension")]}),
("Please plot Interest rate vs business unit ",{"entities":[(12,25,"Measure"),(29,42,"Categorical Dimension")]}),
("Please plot Exceptionals vs zone ",{"entities":[(12,24,"Measure"),(28,32,"Categorical Dimension")]}),
("Please plot Monitoring costs vs gender ",{"entities":[(12,28,"Measure"),(32,38,"Categorical Dimension")]}),
("Please plot Direct Cost vs years of service ",{"entities":[(12,23,"Measure"),(27,43,"Categorical Dimension")]}),
("Please plot Depreciation vs position ",{"entities":[(12,24,"Measure"),(28,36,"Categorical Dimension")]}),
("Please plot Other income vs department ",{"entities":[(12,24,"Measure"),(28,38,"Categorical Dimension")]}),
("Please plot EBIT vs hierarchy ",{"entities":[(12,16,"Measure"),(20,29,"Categorical Dimension")]}),
("Please plot Operating Income vs location ",{"entities":[(12,28,"Measure"),(32,40,"Categorical Dimension")]}),
("Please plot Operating Profit vs division ",{"entities":[(12,28,"Measure"),(32,40,"Categorical Dimension")]}),
("Please plot Cost of Sales vs service group ",{"entities":[(12,25,"Measure"),(29,42,"Categorical Dimension")]}),
("Please plot vacation days vs age group ",{"entities":[(12,25,"Measure"),(29,38,"Categorical Dimension")]}),
("Please plot leavers vs levels ",{"entities":[(12,19,"Measure"),(23,29,"Categorical Dimension")]}),
("Please plot work tenure vs grade ",{"entities":[(12,23,"Measure"),(27,32,"Categorical Dimension")]}),
("Please plot Staff training cost vs accounting_flag ",{"entities":[(12,31,"Measure"),(35,50,"Categorical Dimension")]}),
("Please plot length of service vs accounting_flag ",{"entities":[(12,29,"Measure"),(33,48,"Categorical Dimension")]}),
("Please plot commission vs off_region ",{"entities":[(12,22,"Measure"),(26,36,"Categorical Dimension")]}),
("Please plot workplace injuries vs fund_type_ind ",{"entities":[(12,30,"Measure"),(34,47,"Categorical Dimension")]}),
("Please plot referral count vs StoreResults ",{"entities":[(12,26,"Measure"),(30,42,"Categorical Dimension")]}),
("Please plot number of referrals vs pending ",{"entities":[(12,31,"Measure"),(35,42,"Categorical Dimension")]}),
("Please plot claims payment vs new_items ",{"entities":[(12,26,"Measure"),(30,39,"Categorical Dimension")]}),
("Please plot commission payment vs Claim severity ",{"entities":[(12,30,"Measure"),(34,48,"Categorical Dimension")]}),
("Please plot overtime payment vs Product Name ",{"entities":[(12,28,"Measure"),(32,44,"Categorical Dimension")]}),
("Please plot churn rate vs Product type ",{"entities":[(12,22,"Measure"),(26,38,"Categorical Dimension")]}),
("Please plot employee turnover vs Product category ",{"entities":[(12,29,"Measure"),(33,49,"Categorical Dimension")]}),
("Please plot overtime vs Claim status ",{"entities":[(12,20,"Measure"),(24,36,"Categorical Dimension")]}),
("Please plot referral incentive vs Claim type ",{"entities":[(12,30,"Measure"),(34,44,"Categorical Dimension")]}),
("Please plot LOP vs Basis ",{"entities":[(12,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Please plot Loss of Pay vs Policy Ref ",{"entities":[(12,23,"Measure"),(27,37,"Categorical Dimension")]}),
("Please plot FTE count vs Insd ",{"entities":[(12,21,"Measure"),(25,29,"Categorical Dimension")]}),
("Please plot FTE vacancy count vs Risk Code Pol ",{"entities":[(12,29,"Measure"),(33,46,"Categorical Dimension")]}),
("Please plot vacancy count vs Group Risk Code ",{"entities":[(12,25,"Measure"),(29,44,"Categorical Dimension")]}),
("Please plot vacancy vs BPC Code ",{"entities":[(12,19,"Measure"),(23,31,"Categorical Dimension")]}),
("Please plot filled vacancies vs Division ",{"entities":[(12,28,"Measure"),(32,40,"Categorical Dimension")]}),
("Please plot open vacancies vs Office ",{"entities":[(12,26,"Measure"),(30,36,"Categorical Dimension")]}),
("Please plot joining bonus vs Vertical ",{"entities":[(12,25,"Measure"),(29,37,"Categorical Dimension")]}),
("Please plot notice period vs department ",{"entities":[(12,25,"Measure"),(29,39,"Categorical Dimension")]}),
("Please plot relocation charges vs service line ",{"entities":[(12,30,"Measure"),(34,46,"Categorical Dimension")]}),
("Please plot number of requisitions vs Horizontal ",{"entities":[(12,34,"Measure"),(38,48,"Categorical Dimension")]}),
("Please plot number of resignations vs Vertical ",{"entities":[(12,34,"Measure"),(38,46,"Categorical Dimension")]}),
("Please plot number of promotions vs Geography ",{"entities":[(12,32,"Measure"),(36,45,"Categorical Dimension")]}),
("Please plot number of enrollments vs Sub-business group ",{"entities":[(12,33,"Measure"),(37,55,"Categorical Dimension")]}),
("Please plot workforce tenure vs Business Group ",{"entities":[(12,28,"Measure"),(32,46,"Categorical Dimension")]}),
("Please plot workforce vs Stream ",{"entities":[(12,21,"Measure"),(25,31,"Categorical Dimension")]}),
("Please plot headcount vs Revenue Type ",{"entities":[(12,21,"Measure"),(25,37,"Categorical Dimension")]}),
("Please plot Expected YTD vs broker ",{"entities":[(13,26,"Goal Measure"),(28,34,"Categorical Dimension")]}),
("Please plot Quoted EPI vs lloyd's broker ",{"entities":[(12,22,"Goal Measure"),(26,40,"Categorical Dimension")]}),
("Please plot (PY) Forecast Premium vs event ",{"entities":[(12,28,"Goal Measure"),(32,37,"Categorical Dimension")]}),
("Please plot Forecast Premium vs accounting classes ",{"entities":[(12,28,"Goal Measure"),(32,50,"Categorical Dimension")]}),
("Please plot Revenue Target vs Claim severity ",{"entities":[(12,26,"Goal Measure"),(30,44,"Categorical Dimension")]}),
("Please plot Overheads Budget vs policy holder ",{"entities":[(12,28,"Goal Measure"),(32,45,"Categorical Dimension")]}),
("Please plot EBITDA Budget vs policy type ",{"entities":[(12,26,"Goal Measure"),(29,40,"Categorical Dimension")]}),
("Please plot Revenue Budget vs policy ",{"entities":[(12,27,"Goal Measure"),(30,36,"Categorical Dimension")]}),
("Please plot target headcount vs Product Name ",{"entities":[(12,28,"Goal Measure"),(32,44,"Categorical Dimension")]}),
("GM% vs Region ",{"entities":[(0,3,"Measure"),(7,13,"Categorical Dimension")]}),
("Gross Margin% vs State ",{"entities":[(0,13,"Measure"),(17,22,"Categorical Dimension")]}),
("Profit Margin% vs City ",{"entities":[(0,14,"Measure"),(18,22,"Categorical Dimension")]}),
("Profit% vs Country ",{"entities":[(0,7,"Measure"),(11,18,"Categorical Dimension")]}),
("Profit vs Location ",{"entities":[(0,6,"Measure"),(10,18,"Categorical Dimension")]}),
("Loss% vs length of service slabs ",{"entities":[(0,5,"Measure"),(9,32,"Categorical Dimension")]}),
("Loss vs employee performance ",{"entities":[(0,4,"Measure"),(8,28,"Categorical Dimension")]}),
("Tax vs source ",{"entities":[(0,3,"Measure"),(7,13,"Categorical Dimension")]}),
("Interest rate vs business unit ",{"entities":[(0,13,"Measure"),(17,30,"Categorical Dimension")]}),
("Exceptionals vs zone ",{"entities":[(0,12,"Measure"),(16,20,"Categorical Dimension")]}),
("Monitoring costs vs gender ",{"entities":[(0,16,"Measure"),(20,26,"Categorical Dimension")]}),
("Direct Cost vs years of service ",{"entities":[(0,11,"Measure"),(15,31,"Categorical Dimension")]}),
("Depreciation vs position ",{"entities":[(0,12,"Measure"),(16,24,"Categorical Dimension")]}),
("Other income vs department ",{"entities":[(0,12,"Measure"),(16,26,"Categorical Dimension")]}),
("EBIT vs hierarchy ",{"entities":[(0,4,"Measure"),(8,17,"Categorical Dimension")]}),
("Operating Income vs location ",{"entities":[(0,16,"Measure"),(20,28,"Categorical Dimension")]}),
("Operating Profit vs division ",{"entities":[(0,16,"Measure"),(20,28,"Categorical Dimension")]}),
("Cost of Sales vs service group ",{"entities":[(0,13,"Measure"),(17,30,"Categorical Dimension")]}),
("vacation days vs age group ",{"entities":[(0,13,"Measure"),(17,26,"Categorical Dimension")]}),
("leavers vs levels ",{"entities":[(0,7,"Measure"),(11,17,"Categorical Dimension")]}),
("work tenure vs grade ",{"entities":[(0,11,"Measure"),(15,20,"Categorical Dimension")]}),
("Staff training cost vs accounting_flag ",{"entities":[(0,19,"Measure"),(23,38,"Categorical Dimension")]}),
("length of service vs accounting_flag ",{"entities":[(0,17,"Measure"),(21,36,"Categorical Dimension")]}),
("commission vs off_region ",{"entities":[(0,10,"Measure"),(14,24,"Categorical Dimension")]}),
("workplace injuries vs fund_type_ind ",{"entities":[(0,18,"Measure"),(22,35,"Categorical Dimension")]}),
("referral count vs StoreResults ",{"entities":[(0,14,"Measure"),(18,30,"Categorical Dimension")]}),
("number of referrals vs pending ",{"entities":[(0,19,"Measure"),(23,30,"Categorical Dimension")]}),
("claims payment vs new_items ",{"entities":[(0,14,"Measure"),(18,27,"Categorical Dimension")]}),
("commission payment vs Claim severity ",{"entities":[(0,18,"Measure"),(22,36,"Categorical Dimension")]}),
("overtime payment vs Product Name ",{"entities":[(0,16,"Measure"),(20,32,"Categorical Dimension")]}),
("churn rate vs Product type ",{"entities":[(0,10,"Measure"),(14,26,"Categorical Dimension")]}),
("employee turnover vs Product category ",{"entities":[(0,17,"Measure"),(21,37,"Categorical Dimension")]}),
("overtime vs Claim status ",{"entities":[(0,8,"Measure"),(12,24,"Categorical Dimension")]}),
("referral incentive vs Claim type ",{"entities":[(0,18,"Measure"),(22,32,"Categorical Dimension")]}),
("LOP vs Basis ",{"entities":[(0,3,"Measure"),(7,12,"Categorical Dimension")]}),
("Loss of Pay vs Policy Ref ",{"entities":[(0,11,"Measure"),(15,25,"Categorical Dimension")]}),
("FTE count vs Insd ",{"entities":[(0,9,"Measure"),(13,17,"Categorical Dimension")]}),
("FTE vacancy count vs Risk Code Pol ",{"entities":[(0,17,"Measure"),(21,34,"Categorical Dimension")]}),
("vacancy count vs Group Risk Code ",{"entities":[(0,13,"Measure"),(17,32,"Categorical Dimension")]}),
("vacancy vs BPC Code ",{"entities":[(0,7,"Measure"),(11,19,"Categorical Dimension")]}),
("filled vacancies vs Division ",{"entities":[(0,16,"Measure"),(20,28,"Categorical Dimension")]}),
("open vacancies vs Office ",{"entities":[(0,14,"Measure"),(18,24,"Categorical Dimension")]}),
("joining bonus vs Vertical ",{"entities":[(0,13,"Measure"),(17,25,"Categorical Dimension")]}),
("notice period vs department ",{"entities":[(0,13,"Measure"),(17,27,"Categorical Dimension")]}),
("relocation charges vs service line ",{"entities":[(0,18,"Measure"),(22,34,"Categorical Dimension")]}),
("number of requisitions vs Horizontal ",{"entities":[(0,22,"Measure"),(26,36,"Categorical Dimension")]}),
("number of resignations vs Vertical ",{"entities":[(0,22,"Measure"),(26,34,"Categorical Dimension")]}),
("number of promotions vs Geography ",{"entities":[(0,21,"Measure"),(24,33,"Categorical Dimension")]}),
("number of enrollments vs Sub-business group ",{"entities":[(0,21,"Measure"),(25,43,"Categorical Dimension")]}),
("workforce tenure vs Business Group ",{"entities":[(0,16,"Measure"),(20,34,"Categorical Dimension")]}),
("workforce vs Stream ",{"entities":[(0,9,"Measure"),(13,19,"Categorical Dimension")]}),
("headcount vs Revenue Type ",{"entities":[(0,9,"Measure"),(13,25,"Categorical Dimension")]}),
("redemptions vs position ",{"entities":[(0,11,"Measure"),(15,23,"Categorical Dimension")]}),
("QTDNetSales vs department ",{"entities":[(0,11,"Measure"),(15,25,"Categorical Dimension")]}),
("qtd_sales vs hierarchy ",{"entities":[(0,9,"Measure"),(13,22,"Categorical Dimension")]}),
("qtd_redem vs location ",{"entities":[(0,9,"Measure"),(13,21,"Categorical Dimension")]}),
("pyr_redem vs division ",{"entities":[(0,9,"Measure"),(13,21,"Categorical Dimension")]}),
("pyr_net vs service group ",{"entities":[(0,7,"Measure"),(11,24,"Categorical Dimension")]}),
("avg policy size vs age group ",{"entities":[(0,15,"Measure"),(19,28,"Categorical Dimension")]}),
("underwriting speed vs levels ",{"entities":[(0,18,"Measure"),(22,28,"Categorical Dimension")]}),
("cost per claim vs grade ",{"entities":[(0,14,"Measure"),(18,23,"Categorical Dimension")]}),
("number of referrals vs accounting_flag ",{"entities":[(0,19,"Measure"),(23,38,"Categorical Dimension")]}),
("Premium vs accounting_flag ",{"entities":[(0,7,"Measure"),(11,26,"Categorical Dimension")]}),
("Payout vs off_region ",{"entities":[(0,6,"Measure"),(10,20,"Categorical Dimension")]}),
("Submitted EPI vs fund_type_ind ",{"entities":[(0,13,"Measure"),(17,30,"Categorical Dimension")]}),
("Actual EPI YTD vs StoreResults ",{"entities":[(0,14,"Measure"),(18,30,"Categorical Dimension")]}),
("time to settle a claim vs pending ",{"entities":[(0,22,"Measure"),(26,33,"Categorical Dimension")]}),
("Budget Premium vs new_items ",{"entities":[(0,14,"Measure"),(18,27,"Categorical Dimension")]}),
("PY Actual YTD vs Claim severity ",{"entities":[(1,11,"Measure"),(15,29,"Categorical Dimension")]}),
("Policy Count vs Product Name ",{"entities":[(0,12,"Measure"),(16,28,"Categorical Dimension")]}),
("Limit Remaining vs Product type ",{"entities":[(0,15,"Measure"),(19,31,"Categorical Dimension")]}),
("Plan Remaining vs Product category ",{"entities":[(0,14,"Measure"),(18,34,"Categorical Dimension")]}),
("Plan Remaining % vs Claim status ",{"entities":[(0,16,"Measure"),(20,32,"Categorical Dimension")]}),
("Claim Movement vs Claim type ",{"entities":[(0,14,"Measure"),(18,28,"Categorical Dimension")]}),
("Expiring EPI vs Basis ",{"entities":[(0,12,"Measure"),(16,21,"Categorical Dimension")]}),
("Lost / Lapsed EPI vs Policy Ref ",{"entities":[(0,4,"Measure"),(9,19,"Categorical Dimension")]}),
("Lapsed EPI vs Insd ",{"entities":[(0,10,"Measure"),(14,18,"Categorical Dimension")]}),
("Declinature & NTU EPI vs Risk Code Pol ",{"entities":[(0,21,"Measure"),(25,38,"Categorical Dimension")]}),
("Bound Premium vs Group Risk Code ",{"entities":[(0,13,"Measure"),(17,32,"Categorical Dimension")]}),
("Var % YoY vs BPC Code ",{"entities":[(0,9,"Measure"),(12,21,"Categorical Dimension")]}),
("Var Plan Used % vs Division ",{"entities":[(0,16,"Measure"),(19,27,"Categorical Dimension")]}),
("Benchmark Adequacy vs Office ",{"entities":[(0,18,"Measure"),(22,28,"Categorical Dimension")]}),
("Tech Adequacy vs Vertical ",{"entities":[(0,13,"Measure"),(17,25,"Categorical Dimension")]}),
("Attrition / Attr GILR vs department ",{"entities":[(0,9,"Measure"),(13,23,"Categorical Dimension")]}),
("Loss Ratio / GILR vs service line ",{"entities":[(0,17,"Measure"),(21,33,"Categorical Dimension")]}),
("Yet to Renew vs Horizontal ",{"entities":[(0,12,"Measure"),(16,26,"Categorical Dimension")]}),
(" Prior Yr YTD vs Vertical ",{"entities":[(0,12,"Measure"),(16,24,"Categorical Dimension")]}),
(" Actual YTD vs Geography ",{"entities":[(1,11,"Measure"),(14,23,"Categorical Dimension")]}),
("Prior Yr YOY vs Sub-business group ",{"entities":[(0,12,"Measure"),(16,34,"Categorical Dimension")]}),
(" Variance to Prior Year vs Business Group ",{"entities":[(1,23,"Measure"),(26,40,"Categorical Dimension")]}),
("Renewal % vs Stream ",{"entities":[(0,9,"Measure"),(13,19,"Categorical Dimension")]}),
("New % vs Revenue Type ",{"entities":[(0,5,"Measure"),(9,21,"Categorical Dimension")]}),
("Rate Chg % vs portfolio ",{"entities":[(0,11,"Measure"),(14,23,"Categorical Dimension")]}),
("Retention % vs client ",{"entities":[(0,11,"Measure"),(15,21,"Categorical Dimension")]}),
("Bound Premium vs risk group ",{"entities":[(0,13,"Measure"),(17,27,"Categorical Dimension")]}),
("Overheads vs broker ",{"entities":[(0,9,"Measure"),(13,19,"Categorical Dimension")]}),
("EBITDA vs lloyd's broker ",{"entities":[(0,6,"Measure"),(10,24,"Categorical Dimension")]}),
("Revenue per day vs event ",{"entities":[(0,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Net Profit Margin vs accounting classes ",{"entities":[(0,17,"Measure"),(21,39,"Categorical Dimension")]}),
("GM vs Claim severity ",{"entities":[(0,2,"Measure"),(6,20,"Categorical Dimension")]}),
("Gross Margin vs policy holder ",{"entities":[(0,12,"Measure"),(16,29,"Categorical Dimension")]}),
("Expense vs policy type ",{"entities":[(0,7,"Measure"),(11,22,"Categorical Dimension")]}),
("Revenue vs policy ",{"entities":[(0,7,"Measure"),(11,17,"Categorical Dimension")]}),
("Growth% vs Product Name ",{"entities":[(0,7,"Measure"),(11,23,"Categorical Dimension")]}),
("attrition rate vs Product class ",{"entities":[(0,14,"Measure"),(18,31,"Categorical Dimension")]}),
("layover vs Product type ",{"entities":[(0,7,"Measure"),(11,23,"Categorical Dimension")]}),
("retention rate vs Product category ",{"entities":[(0,14,"Measure"),(18,34,"Categorical Dimension")]}),
("training period vs Carrier ",{"entities":[(0,15,"Measure"),(19,26,"Categorical Dimension")]}),
("ctc vs managing agent ",{"entities":[(0,3,"Measure"),(7,21,"Categorical Dimension")]}),
("time to fill vs agent ",{"entities":[(0,12,"Measure"),(16,21,"Categorical Dimension")]}),
("number of hires vs Claim status ",{"entities":[(0,15,"Measure"),(19,31,"Categorical Dimension")]}),
("number of recruitments vs Claim type ",{"entities":[(0,22,"Measure"),(26,36,"Categorical Dimension")]}),
("recruitment cost vs Age group ",{"entities":[(0,16,"Measure"),(20,29,"Categorical Dimension")]}),
("training days vs Group ",{"entities":[(0,13,"Measure"),(17,22,"Categorical Dimension")]}),
("training cost vs cohort ",{"entities":[(0,13,"Measure"),(17,23,"Categorical Dimension")]}),
("variable pay vs Order status ",{"entities":[(0,12,"Measure"),(16,28,"Categorical Dimension")]}),
("fixed pay vs Status ",{"entities":[(0,9,"Measure"),(13,19,"Categorical Dimension")]}),
("bonus vs Size ",{"entities":[(0,5,"Measure"),(9,13,"Categorical Dimension")]}),
("working hours vs Type ",{"entities":[(0,13,"Measure"),(17,21,"Categorical Dimension")]}),
("experience vs Quality ",{"entities":[(0,10,"Measure"),(14,21,"Categorical Dimension")]}),
("Sick leaves vs Grade ",{"entities":[(0,11,"Measure"),(15,20,"Categorical Dimension")]}),
("earned leaves vs Class ",{"entities":[(0,13,"Measure"),(17,22,"Categorical Dimension")]}),
("salary vs Mode ",{"entities":[(0,6,"Measure"),(10,14,"Categorical Dimension")]}),
("number of employees vs Method ",{"entities":[(0,19,"Measure"),(23,29,"Categorical Dimension")]}),
("dividend rate vs Channel ",{"entities":[(0,13,"Measure"),(17,24,"Categorical Dimension")]}),
("dividend vs Item ",{"entities":[(0,8,"Measure"),(12,16,"Categorical Dimension")]}),
("D/E Ratio vs Department ",{"entities":[(0,9,"Measure"),(13,23,"Categorical Dimension")]}),
("CAPEX vs order type ",{"entities":[(0,5,"Measure"),(8,19,"Categorical Dimension")]}),
("OPEX vs Section ",{"entities":[(0,4,"Measure"),(8,15,"Categorical Dimension")]}),
("Turnover vs Division ",{"entities":[(0,8,"Measure"),(12,20,"Categorical Dimension")]}),
("Working Capital vs Brand ",{"entities":[(0,15,"Measure"),(19,24,"Categorical Dimension")]}),
("Burn rate vs Category ",{"entities":[(0,9,"Measure"),(13,21,"Categorical Dimension")]}),
("OCF vs Lines ",{"entities":[(0,3,"Measure"),(7,12,"Categorical Dimension")]}),
("Operating Cash Flow vs Store ",{"entities":[(0,19,"Measure"),(23,28,"Categorical Dimension")]}),
("EBIT% vs store name ",{"entities":[(0,5,"Measure"),(9,19,"Categorical Dimension")]}),
("EBITDA% vs Zones ",{"entities":[(0,7,"Measure"),(11,16,"Categorical Dimension")]}),
("Operating Profit% vs Block ",{"entities":[(0,17,"Measure"),(21,26,"Categorical Dimension")]}),
("GM% vs Region ",{"entities":[(0,3,"Measure"),(7,13,"Categorical Dimension")]}),
("Gross Margin% vs State ",{"entities":[(0,13,"Measure"),(17,22,"Categorical Dimension")]}),
("Profit Margin% vs City ",{"entities":[(0,14,"Measure"),(18,22,"Categorical Dimension")]}),
("Profit% vs Country ",{"entities":[(0,7,"Measure"),(11,18,"Categorical Dimension")]}),
("Profit vs Location ",{"entities":[(0,6,"Measure"),(10,18,"Categorical Dimension")]}),
("Loss% vs length of service slabs ",{"entities":[(0,5,"Measure"),(9,32,"Categorical Dimension")]}),
("Loss vs employee performance ",{"entities":[(0,4,"Measure"),(8,28,"Categorical Dimension")]}),
("Tax vs source ",{"entities":[(0,3,"Measure"),(7,13,"Categorical Dimension")]}),
("Interest rate vs business unit ",{"entities":[(0,13,"Measure"),(17,30,"Categorical Dimension")]}),
("Exceptionals vs zone ",{"entities":[(0,12,"Measure"),(16,20,"Categorical Dimension")]}),
("Monitoring costs vs gender ",{"entities":[(0,16,"Measure"),(20,26,"Categorical Dimension")]}),
("Direct Cost vs years of service ",{"entities":[(0,11,"Measure"),(15,31,"Categorical Dimension")]}),
("Depreciation vs position ",{"entities":[(0,12,"Measure"),(16,24,"Categorical Dimension")]}),
("Other income vs department ",{"entities":[(0,12,"Measure"),(16,26,"Categorical Dimension")]}),
("EBIT vs hierarchy ",{"entities":[(0,4,"Measure"),(8,17,"Categorical Dimension")]}),
("Operating Income vs location ",{"entities":[(0,16,"Measure"),(20,28,"Categorical Dimension")]}),
("Operating Profit vs division ",{"entities":[(0,16,"Measure"),(20,28,"Categorical Dimension")]}),
("Cost of Sales vs service group ",{"entities":[(0,13,"Measure"),(17,30,"Categorical Dimension")]}),
("vacation days vs age group ",{"entities":[(0,13,"Measure"),(17,26,"Categorical Dimension")]}),
("leavers vs levels ",{"entities":[(0,7,"Measure"),(11,17,"Categorical Dimension")]}),
("work tenure vs grade ",{"entities":[(0,11,"Measure"),(15,20,"Categorical Dimension")]}),
("Staff training cost vs accounting_flag ",{"entities":[(0,19,"Measure"),(23,38,"Categorical Dimension")]}),
("length of service vs accounting_flag ",{"entities":[(0,17,"Measure"),(21,36,"Categorical Dimension")]}),
("commission vs off_region ",{"entities":[(0,10,"Measure"),(14,24,"Categorical Dimension")]}),
("workplace injuries vs fund_type_ind ",{"entities":[(0,18,"Measure"),(22,35,"Categorical Dimension")]}),
("referral count vs StoreResults ",{"entities":[(0,14,"Measure"),(18,30,"Categorical Dimension")]}),
("number of referrals vs pending ",{"entities":[(0,19,"Measure"),(23,30,"Categorical Dimension")]}),
("claims payment vs new_items ",{"entities":[(0,14,"Measure"),(18,27,"Categorical Dimension")]}),
("commission payment vs Claim severity ",{"entities":[(0,18,"Measure"),(22,36,"Categorical Dimension")]}),
("overtime payment vs Product Name ",{"entities":[(0,16,"Measure"),(20,32,"Categorical Dimension")]}),
("churn rate vs Product type ",{"entities":[(0,10,"Measure"),(14,26,"Categorical Dimension")]}),
("employee turnover vs Product category ",{"entities":[(0,17,"Measure"),(21,37,"Categorical Dimension")]}),
("overtime vs Claim status ",{"entities":[(0,8,"Measure"),(12,24,"Categorical Dimension")]}),
("referral incentive vs Claim type ",{"entities":[(0,18,"Measure"),(22,32,"Categorical Dimension")]}),
("LOP vs Basis ",{"entities":[(0,3,"Measure"),(7,12,"Categorical Dimension")]}),
("Loss of Pay vs Policy Ref ",{"entities":[(0,11,"Measure"),(15,25,"Categorical Dimension")]}),
("FTE count vs Insd ",{"entities":[(0,9,"Measure"),(13,17,"Categorical Dimension")]}),
("FTE vacancy count vs Risk Code Pol ",{"entities":[(0,17,"Measure"),(21,34,"Categorical Dimension")]}),
("vacancy count vs Group Risk Code ",{"entities":[(0,13,"Measure"),(17,32,"Categorical Dimension")]}),
("vacancy vs BPC Code ",{"entities":[(0,7,"Measure"),(11,19,"Categorical Dimension")]}),
("filled vacancies vs Division ",{"entities":[(0,16,"Measure"),(20,28,"Categorical Dimension")]}),
("open vacancies vs Office ",{"entities":[(0,14,"Measure"),(18,24,"Categorical Dimension")]}),
("joining bonus vs Vertical ",{"entities":[(0,13,"Measure"),(17,25,"Categorical Dimension")]}),
("notice period vs department ",{"entities":[(0,13,"Measure"),(17,27,"Categorical Dimension")]}),
("relocation charges vs service line ",{"entities":[(0,18,"Measure"),(22,34,"Categorical Dimension")]}),
("number of requisitions vs Horizontal ",{"entities":[(0,22,"Measure"),(26,36,"Categorical Dimension")]}),
("number of resignations vs Vertical ",{"entities":[(0,22,"Measure"),(26,34,"Categorical Dimension")]}),
("number of promotions vs Geography ",{"entities":[(0,21,"Measure"),(24,33,"Categorical Dimension")]}),
("number of enrollments vs Sub-business group ",{"entities":[(0,21,"Measure"),(25,43,"Categorical Dimension")]}),
("workforce tenure vs Business Group ",{"entities":[(0,16,"Measure"),(20,34,"Categorical Dimension")]}),
("workforce vs Stream ",{"entities":[(0,9,"Measure"),(13,19,"Categorical Dimension")]}),
("headcount vs Revenue Type ",{"entities":[(0,9,"Measure"),(13,25,"Categorical Dimension")]}),
("completed_mtd vs Product class ",{"entities":[(0,13,"Measure"),(17,30,"Categorical Dimension")]}),
("completed_items vs Product type ",{"entities":[(0,15,"Measure"),(19,31,"Categorical Dimension")]}),
("AUM vs Product category ",{"entities":[(0,3,"Measure"),(7,23,"Categorical Dimension")]}),
("AsOf_sales vs Carrier ",{"entities":[(0,10,"Measure"),(14,21,"Categorical Dimension")]}),
("net_ytd vs managing agent ",{"entities":[(0,7,"Measure"),(11,25,"Categorical Dimension")]}),
("net_today vs agent ",{"entities":[(0,9,"Measure"),(13,18,"Categorical Dimension")]}),
("Net_Sales vs Claim status ",{"entities":[(0,9,"Measure"),(13,25,"Categorical Dimension")]}),
("net_mtd vs Claim type ",{"entities":[(0,7,"Measure"),(11,21,"Categorical Dimension")]}),
("Net_AFB vs Age group ",{"entities":[(0,7,"Measure"),(11,20,"Categorical Dimension")]}),
("MTDNetSales vs Group ",{"entities":[(0,11,"Measure"),(15,20,"Categorical Dimension")]}),
("mtd_sales_afb vs cohort ",{"entities":[(0,14,"Measure"),(17,23,"Categorical Dimension")]}),
("mtd_sales vs Order status ",{"entities":[(0,9,"Measure"),(13,25,"Categorical Dimension")]}),
("mtd_redem_afb vs Status ",{"entities":[(0,13,"Measure"),(17,23,"Categorical Dimension")]}),
("mtd_redem vs Size ",{"entities":[(0,9,"Measure"),(13,17,"Categorical Dimension")]}),
("mtd_percent vs Type ",{"entities":[(0,11,"Measure"),(15,19,"Categorical Dimension")]}),
("mtd_net_flow vs Quality ",{"entities":[(0,12,"Measure"),(16,23,"Categorical Dimension")]}),
("mtd_net vs Grade ",{"entities":[(0,7,"Measure"),(11,16,"Categorical Dimension")]}),
("MTD% vs Class ",{"entities":[(0,4,"Measure"),(8,13,"Categorical Dimension")]}),
("mtd vs Mode ",{"entities":[(0,3,"Measure"),(7,11,"Categorical Dimension")]}),
("YTDNetSales vs Method ",{"entities":[(0,11,"Measure"),(15,21,"Categorical Dimension")]}),
("ytd_sales_afb vs Channel ",{"entities":[(0,13,"Measure"),(17,24,"Categorical Dimension")]}),
("ytd_sales vs Item ",{"entities":[(0,9,"Measure"),(13,17,"Categorical Dimension")]}),
("ytd_redem_afb vs Department ",{"entities":[(0,13,"Measure"),(17,27,"Categorical Dimension")]}),
("ytd_redem vs order type ",{"entities":[(0,9,"Measure"),(13,23,"Categorical Dimension")]}),
("ytd_percent vs Section ",{"entities":[(0,11,"Measure"),(15,22,"Categorical Dimension")]}),
("ytd_net_flow vs Division ",{"entities":[(0,12,"Measure"),(16,24,"Categorical Dimension")]}),
("ytd_net vs Brand ",{"entities":[(0,7,"Measure"),(11,16,"Categorical Dimension")]}),
("YTD% vs Category ",{"entities":[(0,4,"Measure"),(8,16,"Categorical Dimension")]}),
("ytd vs Lines ",{"entities":[(0,3,"Measure"),(7,12,"Categorical Dimension")]}),
("usd_amt vs Store ",{"entities":[(0,7,"Measure"),(11,16,"Categorical Dimension")]}),
("total_sales_afb vs store name ",{"entities":[(0,15,"Measure"),(19,29,"Categorical Dimension")]}),
("total_sales vs Zones ",{"entities":[(0,11,"Measure"),(15,20,"Categorical Dimension")]}),
("total_redem_afb vs Block ",{"entities":[(0,15,"Measure"),(19,24,"Categorical Dimension")]}),
("total_redem vs Region ",{"entities":[(0,11,"Measure"),(15,21,"Categorical Dimension")]}),
("total_pending vs State ",{"entities":[(0,13,"Measure"),(17,22,"Categorical Dimension")]}),
("today_sales_afb vs City ",{"entities":[(0,15,"Measure"),(19,23,"Categorical Dimension")]}),
("today_sales vs Country ",{"entities":[(0,11,"Measure"),(15,22,"Categorical Dimension")]}),
("today_redem_afb vs Location ",{"entities":[(0,15,"Measure"),(19,27,"Categorical Dimension")]}),
("today_redem vs length of service slabs ",{"entities":[(0,11,"Measure"),(15,38,"Categorical Dimension")]}),
("today_net_flow vs employee performance ",{"entities":[(0,14,"Measure"),(18,38,"Categorical Dimension")]}),
("today_net vs source ",{"entities":[(0,9,"Measure"),(13,19,"Categorical Dimension")]}),
("today vs business unit ",{"entities":[(0,5,"Measure"),(9,22,"Categorical Dimension")]}),
("sales_afb vs zone ",{"entities":[(0,9,"Measure"),(13,17,"Categorical Dimension")]}),
("sales vs gender ",{"entities":[(0,5,"Measure"),(9,15,"Categorical Dimension")]}),
("redemptions_afb vs years of service ",{"entities":[(0,15,"Measure"),(19,35,"Categorical Dimension")]}),
("Lapsed EPI vs Policy Ref ",{"entities":[(0,10,"Measure"),(14,24,"Categorical Dimension")]}),
("Attr GILR vs department ",{"entities":[(0,9,"Measure"),(13,23,"Categorical Dimension")]}),
("Expected YTD vs broker ",{"entities":[(1,13,"Goal Measure"),(16,22,"Categorical Dimension")]}),
("Quoted EPI vs lloyd's broker ",{"entities":[(0,10,"Goal Measure"),(14,28,"Categorical Dimension")]}),
("(PY) Forecast Premium vs event ",{"entities":[(0,16,"Goal Measure"),(20,25,"Categorical Dimension")]}),
("Forecast Premium vs accounting classes ",{"entities":[(0,16,"Goal Measure"),(20,38,"Categorical Dimension")]}),
("Revenue Target vs Claim severity ",{"entities":[(0,14,"Goal Measure"),(18,32,"Categorical Dimension")]}),
("Overheads Budget vs policy holder ",{"entities":[(0,16,"Goal Measure"),(20,33,"Categorical Dimension")]}),
("EBITDA Budget vs policy type ",{"entities":[(0,13,"Goal Measure"),(17,28,"Categorical Dimension")]}),
("Revenue Budget vs policy ",{"entities":[(0,14,"Goal Measure"),(18,24,"Categorical Dimension")]}),
("target headcount vs Product Name ",{"entities":[(0,16,"Goal Measure"),(20,32,"Categorical Dimension")]}),
("Plot my Net Profit Margin against my accounting classes ",{"entities":[(8,25,"Measure"),(37,55,"Categorical Dimension")]}),
("Plot my GM against my Claim severity ",{"entities":[(8,10,"Measure"),(22,36,"Categorical Dimension")]}),
("Plot my Gross Margin against my policy holder ",{"entities":[(8,19,"Measure"),(32,45,"Categorical Dimension")]}),
("Plot my Expense against my policy type ",{"entities":[(8,15,"Measure"),(27,38,"Categorical Dimension")]}),
("Plot my Revenue against my policy ",{"entities":[(8,15,"Measure"),(27,33,"Categorical Dimension")]}),
("Plot my Growth% against my Product Name ",{"entities":[(8,15,"Measure"),(27,39,"Categorical Dimension")]}),
("Plot my attrition rate against my Product class ",{"entities":[(8,22,"Measure"),(34,47,"Categorical Dimension")]}),
("Plot my layover against my Product type ",{"entities":[(8,15,"Measure"),(27,39,"Categorical Dimension")]}),
("Plot my retention rate against my Product category ",{"entities":[(8,22,"Measure"),(34,50,"Categorical Dimension")]}),
("Plot my training period against my Carrier ",{"entities":[(8,23,"Measure"),(35,42,"Categorical Dimension")]}),
("Plot my ctc against my managing agent ",{"entities":[(8,11,"Measure"),(23,37,"Categorical Dimension")]}),
("Plot my time to fill against my agent ",{"entities":[(8,20,"Measure"),(32,37,"Categorical Dimension")]}),
("Plot my number of hires against my Claim status ",{"entities":[(8,23,"Measure"),(35,47,"Categorical Dimension")]}),
("Plot my number of recruitments against my Claim type ",{"entities":[(8,30,"Measure"),(42,52,"Categorical Dimension")]}),
("Plot my recruitment cost against my Age group ",{"entities":[(8,24,"Measure"),(36,45,"Categorical Dimension")]}),
("Plot my training days against my Group ",{"entities":[(8,21,"Measure"),(33,38,"Categorical Dimension")]}),
("Plot my training cost against my cohort ",{"entities":[(8,21,"Measure"),(33,39,"Categorical Dimension")]}),
("Plot my variable pay against my Order status ",{"entities":[(8,20,"Measure"),(32,44,"Categorical Dimension")]}),
("Plot my fixed pay against my Status ",{"entities":[(8,17,"Measure"),(29,35,"Categorical Dimension")]}),
("Plot my bonus against my Size ",{"entities":[(8,13,"Measure"),(25,29,"Categorical Dimension")]}),
("Plot my working hours against my Type ",{"entities":[(8,21,"Measure"),(33,37,"Categorical Dimension")]}),
("Plot my experience against my Quality ",{"entities":[(8,18,"Measure"),(30,37,"Categorical Dimension")]}),
("Plot my Sick leaves against my Grade ",{"entities":[(8,19,"Measure"),(31,36,"Categorical Dimension")]}),
("Plot my earned leaves against my Class ",{"entities":[(8,21,"Measure"),(33,38,"Categorical Dimension")]}),
("Plot my salary against my Mode ",{"entities":[(7,14,"Measure"),(26,30,"Categorical Dimension")]}),
("Plot my number of employees against my Method ",{"entities":[(8,27,"Measure"),(39,45,"Categorical Dimension")]}),
("Plot my dividend rate against my Channel ",{"entities":[(8,21,"Measure"),(33,40,"Categorical Dimension")]}),
("Plot my dividend against my Item ",{"entities":[(8,16,"Measure"),(28,32,"Categorical Dimension")]}),
("Plot my D/E Ratio against my Department ",{"entities":[(8,17,"Measure"),(29,39,"Categorical Dimension")]}),
("Plot my CAPEX against my order type ",{"entities":[(8,13,"Measure"),(25,35,"Categorical Dimension")]}),
("Plot my OPEX against my Section ",{"entities":[(8,13,"Measure"),(24,31,"Categorical Dimension")]}),
("Plot my Turnover against my Division ",{"entities":[(8,16,"Measure"),(28,36,"Categorical Dimension")]}),
("Plot my Working Capital against my Brand ",{"entities":[(8,23,"Measure"),(35,40,"Categorical Dimension")]}),
("Plot my Burn rate against my Category ",{"entities":[(8,17,"Measure"),(29,37,"Categorical Dimension")]}),
("Plot my OCF against my Lines ",{"entities":[(8,11,"Measure"),(23,28,"Categorical Dimension")]}),
("Plot my Operating Cash Flow against my Store ",{"entities":[(8,27,"Measure"),(39,44,"Categorical Dimension")]}),
("Plot my EBIT% against my store name ",{"entities":[(8,13,"Measure"),(25,35,"Categorical Dimension")]}),
("Plot my EBITDA% against my Zones ",{"entities":[(8,15,"Measure"),(27,32,"Categorical Dimension")]}),
("Plot my Operating Profit% against my Block ",{"entities":[(8,25,"Measure"),(37,42,"Categorical Dimension")]}),
("Plot my GM% against my Region ",{"entities":[(8,11,"Measure"),(23,29,"Categorical Dimension")]}),
("Plot my Gross Margin% against my State ",{"entities":[(8,21,"Measure"),(33,38,"Categorical Dimension")]}),
("Plot my Profit Margin% against my City ",{"entities":[(8,22,"Measure"),(34,38,"Categorical Dimension")]}),
("Plot my Profit% against my Country ",{"entities":[(8,15,"Measure"),(27,34,"Categorical Dimension")]}),
("Plot my Profit against my Location ",{"entities":[(8,14,"Measure"),(26,34,"Categorical Dimension")]}),
("Plot my Loss% against my length of service slabs ",{"entities":[(8,13,"Measure"),(25,48,"Categorical Dimension")]}),
("Plot my Loss against my employee performance ",{"entities":[(8,12,"Measure"),(24,44,"Categorical Dimension")]}),
("Plot my Tax against my source ",{"entities":[(8,11,"Measure"),(23,29,"Categorical Dimension")]}),
("Plot my Interest rate against my business unit ",{"entities":[(8,21,"Measure"),(33,46,"Categorical Dimension")]}),
("Plot my Exceptionals against my zone ",{"entities":[(8,20,"Measure"),(32,36,"Categorical Dimension")]}),
("Plot my Monitoring costs against my gender ",{"entities":[(8,24,"Measure"),(36,42,"Categorical Dimension")]}),
("Plot my Direct Cost against my years of service ",{"entities":[(8,19,"Measure"),(31,47,"Categorical Dimension")]}),
("Plot my Depreciation against my position ",{"entities":[(8,19,"Measure"),(32,40,"Categorical Dimension")]}),
("Plot my Other income against my department ",{"entities":[(8,20,"Measure"),(32,42,"Categorical Dimension")]}),
("Plot my EBIT against my hierarchy ",{"entities":[(8,12,"Measure"),(24,33,"Categorical Dimension")]}),
("Plot my Operating Income against my location ",{"entities":[(8,24,"Measure"),(36,44,"Categorical Dimension")]}),
("Plot my Operating Profit against my division ",{"entities":[(8,24,"Measure"),(36,44,"Categorical Dimension")]}),
("Plot my Cost of Sales against my service group ",{"entities":[(8,21,"Measure"),(33,46,"Categorical Dimension")]}),
("Plot my vacation days against my age group ",{"entities":[(8,21,"Measure"),(33,42,"Categorical Dimension")]}),
("Plot my leavers against my levels ",{"entities":[(8,15,"Measure"),(27,33,"Categorical Dimension")]}),
("Plot my work tenure against my grade ",{"entities":[(8,19,"Measure"),(31,36,"Categorical Dimension")]}),
("Plot my Staff training cost against my accounting_flag ",{"entities":[(8,27,"Measure"),(39,54,"Categorical Dimension")]}),
("Plot my length of service against my accounting_flag ",{"entities":[(8,25,"Measure"),(37,52,"Categorical Dimension")]}),
("Plot my commission against my off_region ",{"entities":[(8,18,"Measure"),(30,40,"Categorical Dimension")]}),
("Plot my workplace injuries against my fund_type_ind ",{"entities":[(8,26,"Measure"),(38,51,"Categorical Dimension")]}),
("Plot my referral count against my StoreResults ",{"entities":[(8,22,"Measure"),(34,46,"Categorical Dimension")]}),
("Plot my number of referrals against my pending ",{"entities":[(8,27,"Measure"),(39,46,"Categorical Dimension")]}),
("Plot my claims payment against my new_items ",{"entities":[(8,22,"Measure"),(34,43,"Categorical Dimension")]}),
("Plot my commission payment against my Claim severity ",{"entities":[(8,26,"Measure"),(38,52,"Categorical Dimension")]}),
("Plot my overtime payment against my Product Name ",{"entities":[(8,24,"Measure"),(36,48,"Categorical Dimension")]}),
("Plot my churn rate against my Product type ",{"entities":[(8,18,"Measure"),(30,42,"Categorical Dimension")]}),
("Plot my employee turnover against my Product category ",{"entities":[(8,25,"Measure"),(37,53,"Categorical Dimension")]}),
("Plot my overtime against my Claim status ",{"entities":[(8,16,"Measure"),(28,40,"Categorical Dimension")]}),
("Plot my referral incentive against my Claim type ",{"entities":[(8,26,"Measure"),(38,48,"Categorical Dimension")]}),
("Plot my LOP against my Basis ",{"entities":[(8,11,"Measure"),(23,28,"Categorical Dimension")]}),
("Plot my Loss of Pay against my Policy Ref ",{"entities":[(8,19,"Measure"),(31,41,"Categorical Dimension")]}),
("Plot my FTE count against my Insd ",{"entities":[(8,11,"Measure"),(29,33,"Categorical Dimension")]}),
("Plot my FTE vacancy count against my Risk Code Pol ",{"entities":[(8,25,"Measure"),(37,50,"Categorical Dimension")]}),
("Plot my vacancy count against my Group Risk Code ",{"entities":[(8,21,"Measure"),(33,48,"Categorical Dimension")]}),
("Plot my vacancy against my BPC Code ",{"entities":[(8,15,"Measure"),(27,35,"Categorical Dimension")]}),
("Plot my filled vacancies against my Division ",{"entities":[(8,24,"Measure"),(36,44,"Categorical Dimension")]}),
("Plot my open vacancies against my Office ",{"entities":[(8,22,"Measure"),(34,40,"Categorical Dimension")]}),
("Plot my joining bonus against my Vertical ",{"entities":[(8,20,"Measure"),(33,41,"Categorical Dimension")]}),
("Plot my notice period against my department ",{"entities":[(8,21,"Measure"),(33,43,"Categorical Dimension")]}),
("Plot my relocation charges against my service line ",{"entities":[(8,26,"Measure"),(38,50,"Categorical Dimension")]}),
("Plot my number of requisitions against my Horizontal ",{"entities":[(8,29,"Measure"),(42,52,"Categorical Dimension")]}),
("Plot my number of resignations against my Vertical ",{"entities":[(8,30,"Measure"),(42,50,"Categorical Dimension")]}),
("Plot my number of promotions against my Geography ",{"entities":[(8,28,"Measure"),(40,49,"Categorical Dimension")]}),
("Plot my number of enrollments against my Sub-business group ",{"entities":[(8,29,"Measure"),(41,59,"Categorical Dimension")]}),
("Plot my workforce tenure against my Business Group ",{"entities":[(8,24,"Measure"),(36,50,"Categorical Dimension")]}),
("Plot my workforce against my Stream ",{"entities":[(8,17,"Measure"),(29,35,"Categorical Dimension")]}),
("Plot my headcount against my Revenue Type ",{"entities":[(8,17,"Measure"),(29,41,"Categorical Dimension")]}),
("Plot my completed_mtd against my Product class",{"entities":[(8,21,"Measure"),(33,46,"Categorical Dimension")]}),
("Plot my completed_items against my Product type ",{"entities":[(8,23,"Measure"),(35,47,"Categorical Dimension")]}),
("Plot my AUM against my Product category ",{"entities":[(8,11,"Measure"),(23,39,"Categorical Dimension")]}),
("Plot my AsOf_sales against my Carrier ",{"entities":[(8,18,"Measure"),(30,37,"Categorical Dimension")]}),
("Plot my net_ytd against my managing agent ",{"entities":[(8,15,"Measure"),(27,41,"Categorical Dimension")]}),
("Plot my net_today against my agent ",{"entities":[(8,17,"Measure"),(29,34,"Categorical Dimension")]}),
("Plot my Net_Sales against my Claim status ",{"entities":[(8,17,"Measure"),(29,41,"Categorical Dimension")]}),
("Plot my net_mtd against my Claim type ",{"entities":[(8,15,"Measure"),(27,37,"Categorical Dimension")]}),
("Plot my Net_AFB against my Age group ",{"entities":[(8,15,"Measure"),(27,36,"Categorical Dimension")]}),
("Plot my MTDNetSales against my Group ",{"entities":[(8,19,"Measure"),(31,36,"Categorical Dimension")]}),
("Plot my mtd_sales_afb against my cohort ",{"entities":[(8,21,"Measure"),(33,39,"Categorical Dimension")]}),
("Plot my mtd_sales against my Order status ",{"entities":[(8,17,"Measure"),(29,41,"Categorical Dimension")]}),
("Plot my mtd_redem_afb against my Status ",{"entities":[(8,21,"Measure"),(33,39,"Categorical Dimension")]}),
("Plot my mtd_redem against my Size ",{"entities":[(8,17,"Measure"),(29,33,"Categorical Dimension")]}),
("Plot my mtd_percent against my Type ",{"entities":[(8,19,"Measure"),(31,35,"Categorical Dimension")]}),
("Plot my mtd_net_flow against my Quality ",{"entities":[(8,20,"Measure"),(32,39,"Categorical Dimension")]}),
("Plot my mtd_net against my Grade ",{"entities":[(8,15,"Measure"),(27,32,"Categorical Dimension")]}),
("Plot my MTD% against my Class ",{"entities":[(8,12,"Measure"),(24,29,"Categorical Dimension")]}),
("Plot my mtd against my Mode ",{"entities":[(8,11,"Measure"),(23,27,"Categorical Dimension")]}),
("Plot my YTDNetSales against my Method ",{"entities":[(8,19,"Measure"),(31,37,"Categorical Dimension")]}),
("Plot my ytd_sales_afb against my Channel ",{"entities":[(8,21,"Measure"),(33,40,"Categorical Dimension")]}),
("Plot my ytd_sales against my Item ",{"entities":[(8,17,"Measure"),(29,33,"Categorical Dimension")]}),
("Plot my ytd_redem_afb against my Department ",{"entities":[(8,21,"Measure"),(33,43,"Categorical Dimension")]}),
("Plot my ytd_redem against my order type ",{"entities":[(8,17,"Measure"),(29,39,"Categorical Dimension")]}),
("Plot my ytd_percent against my Section ",{"entities":[(8,19,"Measure"),(31,38,"Categorical Dimension")]}),
("Plot my ytd_net_flow against my Division ",{"entities":[(8,20,"Measure"),(32,40,"Categorical Dimension")]}),
("Plot my ytd_net against my Brand ",{"entities":[(8,15,"Measure"),(27,32,"Categorical Dimension")]}),
("Plot my YTD% against my Category ",{"entities":[(8,12,"Measure"),(24,32,"Categorical Dimension")]}),
("Plot my ytd against my Lines ",{"entities":[(8,11,"Measure"),(23,28,"Categorical Dimension")]}),
("Plot my usd_amt against my Store ",{"entities":[(8,15,"Measure"),(27,32,"Categorical Dimension")]}),
("Plot my total_sales_afb against my store name ",{"entities":[(8,23,"Measure"),(35,45,"Categorical Dimension")]}),
("Plot my total_sales against my Zones ",{"entities":[(8,19,"Measure"),(31,36,"Categorical Dimension")]}),
("Plot my total_redem_afb against my Block ",{"entities":[(8,23,"Measure"),(35,40,"Categorical Dimension")]}),
("Plot my total_redem against my Region ",{"entities":[(8,18,"Measure"),(31,37,"Categorical Dimension")]}),
("Plot my total_pending against my State ",{"entities":[(8,21,"Measure"),(33,38,"Categorical Dimension")]}),
("Plot my today_sales_afb against my City ",{"entities":[(8,23,"Measure"),(35,39,"Categorical Dimension")]}),
("Plot my today_sales against my Country ",{"entities":[(8,19,"Measure"),(31,38,"Categorical Dimension")]}),
("Plot my today_redem_afb against my Location ",{"entities":[(8,23,"Measure"),(35,43,"Categorical Dimension")]}),
("Plot my today_redem against my length of service slabs ",{"entities":[(8,19,"Measure"),(31,54,"Categorical Dimension")]}),
("Plot my today_net_flow against my employee performance ",{"entities":[(8,22,"Measure"),(34,54,"Categorical Dimension")]}),
("Plot my today_net against my source ",{"entities":[(8,17,"Measure"),(29,35,"Categorical Dimension")]}),
("Plot my today against my business unit ",{"entities":[(8,13,"Measure"),(25,38,"Categorical Dimension")]}),
("Plot my sales_afb against my zone ",{"entities":[(8,17,"Measure"),(29,33,"Categorical Dimension")]}),
("Plot my sales against my gender ",{"entities":[(8,13,"Measure"),(25,31,"Categorical Dimension")]}),
("Plot my redemptions_afb against my years of service ",{"entities":[(8,23,"Measure"),(35,51,"Categorical Dimension")]}),
("Plot my redemptions against my position ",{"entities":[(8,19,"Measure"),(31,39,"Categorical Dimension")]}),
("Plot my QTDNetSales against my department ",{"entities":[(8,19,"Measure"),(31,41,"Categorical Dimension")]}),
("Plot my qtd_sales against my hierarchy ",{"entities":[(8,17,"Measure"),(29,38,"Categorical Dimension")]}),
("Plot my qtd_redem against my location ",{"entities":[(8,17,"Measure"),(29,37,"Categorical Dimension")]}),
("Plot my pyr_redem against my division ",{"entities":[(8,17,"Measure"),(29,37,"Categorical Dimension")]}),
("Plot my pyr_net against my service group ",{"entities":[(8,15,"Measure"),(27,40,"Categorical Dimension")]}),
("Plot my avg policy size against my age group ",{"entities":[(8,23,"Measure"),(35,44,"Categorical Dimension")]}),
("Plot my underwriting speed against my levels ",{"entities":[(8,26,"Measure"),(35,44,"Categorical Dimension")]}),
("Plot my cost per claim against my grade ",{"entities":[(8,22,"Measure"),(31,39,"Categorical Dimension")]}),
("Plot my number of referrals against my accounting_flag ",{"entities":[(8,27,"Measure"),(39,54,"Categorical Dimension")]}),
("Plot my Premium against my accounting_flag ",{"entities":[(8,15,"Measure"),(27,42,"Categorical Dimension")]}),
("Plot my Payout against my off_region ",{"entities":[(8,14,"Measure"),(26,36,"Categorical Dimension")]}),
("Plot my Submitted EPI against my fund_type_ind ",{"entities":[(8,21,"Measure"),(33,46,"Categorical Dimension")]}),
("Plot my Actual EPI YTD against my StoreResults ",{"entities":[(8,22,"Measure"),(34,46,"Categorical Dimension")]}),
("Plot my time to settle a claim against my pending ",{"entities":[(8,30,"Measure"),(42,49,"Categorical Dimension")]}),
("Plot my Budget Premium against my new_items ",{"entities":[(8,22,"Measure"),(34,43,"Categorical Dimension")]}),
("Plot my PY Actual YTD against my Claim severity ",{"entities":[(8,18,"Measure"),(30,44,"Categorical Dimension")]}),
("Plot my Policy Count against my Product Name ",{"entities":[(8,20,"Measure"),(32,44,"Categorical Dimension")]}),
("Plot my Limit Remaining against my Product type ",{"entities":[(8,23,"Measure"),(35,47,"Categorical Dimension")]}),
("Plot my Plan Remaining against my Product category ",{"entities":[(8,22,"Measure"),(34,50,"Categorical Dimension")]}),
("Plot my Plan Remaining % against my Claim status ",{"entities":[(8,24,"Measure"),(36,48,"Categorical Dimension")]}),
("Plot my Claim Movement against my Claim type ",{"entities":[(8,22,"Measure"),(34,44,"Categorical Dimension")]}),
("Plot my Expiring EPI against my Basis ",{"entities":[(8,20,"Measure"),(32,37,"Categorical Dimension")]}),
("Plot my Lost / Lapsed EPI against my Policy Ref ",{"entities":[(8,18,"Measure"),(30,40,"Categorical Dimension")]}),
("Plot my Lapsed EPI against my Insd ",{"entities":[(8,18,"Measure"),(30,34,"Categorical Dimension")]}),
("Plot my Declinature & NTU EPI against my Risk Code Pol ",{"entities":[(8,29,"Measure"),(41,54,"Categorical Dimension")]}),
("Plot my Bound Premium against my Group Risk Code ",{"entities":[(8,21,"Measure"),(33,48,"Categorical Dimension")]}),
("Plot my Var % YoY against my BPC Code ",{"entities":[(8,13,"Measure"),(26,34,"Categorical Dimension")]}),
("Plot my Var Plan Used % against my Division ",{"entities":[(8,23,"Measure"),(35,43,"Categorical Dimension")]}),
("Plot my Benchmark Adequacy against my Office ",{"entities":[(8,27,"Measure"),(38,44,"Categorical Dimension")]}),
("Plot my Tech Adequacy against my Vertical ",{"entities":[(7,21,"Measure"),(33,41,"Categorical Dimension")]}),
("Plot my Attrition / Attr GILR against my department ",{"entities":[(8,17,"Measure"),(29,39,"Categorical Dimension")]}),
("Plot my Loss Ratio / GILR against my service line ",{"entities":[(8,19,"Measure"),(31,43,"Categorical Dimension")]}),
("Plot my Yet to Renew against my Horizontal ",{"entities":[(8,20,"Measure"),(32,42,"Categorical Dimension")]}),
("Plot my Prior Yr YTD against my Vertical ",{"entities":[(9,21,"Measure"),(32,40,"Categorical Dimension")]}),
("Plot my Actual YTD against my Geography ",{"entities":[(9,19,"Measure"),(30,39,"Categorical Dimension")]}),
("Plot my Prior Yr YOY against my Sub-business group ",{"entities":[(8,20,"Measure"),(32,50,"Categorical Dimension")]}),
("Plot my Variance to Prior Year against my Business Group ",{"entities":[(9,31,"Measure"),(42,56,"Categorical Dimension")]}),
("Plot my Renewal % against my Stream ",{"entities":[(8,17,"Measure"),(29,35,"Categorical Dimension")]}),
("Plot my New % against my Revenue Type ",{"entities":[(8,13,"Measure"),(25,37,"Categorical Dimension")]}),
("Plot my Rate Chg % against my portfolio ",{"entities":[(8,18,"Measure"),(30,39,"Categorical Dimension")]}),
("Plot my Retention % against my client ",{"entities":[(8,19,"Measure"),(31,37,"Categorical Dimension")]}),
("Plot my Bound Premium against my risk group ",{"entities":[(8,21,"Measure"),(33,43,"Categorical Dimension")]}),
("Plot my Overheads against my broker ",{"entities":[(8,17,"Measure"),(29,35,"Categorical Dimension")]}),
("Plot my EBITDA against my lloyd's broker ",{"entities":[(8,14,"Measure"),(26,40,"Categorical Dimension")]}),
("Plot my Revenue per day against my event ",{"entities":[(8,23,"Measure"),(35,40,"Categorical Dimension")]}),
("Plot my Lost/ Lapsed EPI against my Policy Ref ",{"entities":[(8,24,"Measure"),(36,46,"Categorical Dimension")]}),
("Plot my Attr GILR against my department ",{"entities":[(9,18,"Measure"),(29,39,"Categorical Dimension")]}),
("Plot my GILR against my service line ",{"entities":[(8,12,"Measure"),(24,36,"Categorical Dimension")]}),
("Plot my Expected YTD against my broker",{"entities":[(9,21,"Measure"),(32,38,"Categorical Dimension")]}),
("Plot my Quoted EPI against my lloyd's broker ",{"entities":[(8,18,"Measure"),(30,44,"Categorical Dimension")]}),
("Plot my (PY) Forecast Premium against my event ",{"entities":[(8,24,"Measure"),(36,41,"Categorical Dimension")]}),
("Plot my Forecast Premium against my accounting classes ",{"entities":[(8,24,"Measure"),(36,54,"Categorical Dimension")]}),
("Plot my Revenue Target against my Claim severity ",{"entities":[(8,22,"Measure"),(34,48,"Categorical Dimension")]}),
("Plot my Overheads Budget against my policy holder ",{"entities":[(8,24,"Measure"),(36,49,"Categorical Dimension")]}),
("Plot my EBITDA Budget against my policy type ",{"entities":[(8,21,"Measure"),(33,44,"Categorical Dimension")]}),
("Plot my Revenue Budget against my policy ",{"entities":[(8,22,"Measure"),(34,40,"Categorical Dimension")]}),
("Plot my target headcount against my Product Name ",{"entities":[(8,24,"Measure"),(36,48,"Categorical Dimension")]}),
("I would like to see my layover for different Product type ",{"entities":[(23,30,"Measure"),(45,57,"Categorical Dimension")]}),
("I would like to see my retention rate for different Product category ",{"entities":[(23,37,"Measure"),(52,68,"Categorical Dimension")]}),
("I would like to see my training period for different Carrier ",{"entities":[(23,38,"Measure"),(53,60,"Categorical Dimension")]}),
("I would like to see my ctc for different managing agent ",{"entities":[(23,26,"Measure"),(41,55,"Categorical Dimension")]}),
("I would like to see my time to fill for different agent ",{"entities":[(23,35,"Measure"),(50,55,"Categorical Dimension")]}),
("I would like to see my number of hires for different Claim status ",{"entities":[(23,38,"Measure"),(53,65,"Categorical Dimension")]}),
("I would like to see my number of recruitments for different Claim type ",{"entities":[(23,45,"Measure"),(60,70,"Categorical Dimension")]}),
("I would like to see my recruitment cost for different Age group ",{"entities":[(23,39,"Measure"),(54,63,"Categorical Dimension")]}),
("I would like to see my training days for different Group ",{"entities":[(23,36,"Measure"),(51,56,"Categorical Dimension")]}),
("I would like to see my training cost for different cohort ",{"entities":[(23,36,"Measure"),(51,57,"Categorical Dimension")]}),
("I would like to see my variable pay for different Order status ",{"entities":[(23,35,"Measure"),(50,62,"Categorical Dimension")]}),
("I would like to see my fixed pay for different Status ",{"entities":[(23,32,"Measure"),(47,53,"Categorical Dimension")]}),
("I would like to see my bonus for different Size ",{"entities":[(23,28,"Measure"),(43,47,"Categorical Dimension")]}),
("I would like to see my working hours for different Type ",{"entities":[(23,36,"Measure"),(51,55,"Categorical Dimension")]}),
("I would like to see my experience for different Quality ",{"entities":[(23,33,"Measure"),(48,55,"Categorical Dimension")]}),
("I would like to see my Sick leaves for different Grade ",{"entities":[(23,34,"Measure"),(49,54,"Categorical Dimension")]}),
("I would like to see my earned leaves for different Class ",{"entities":[(23,36,"Measure"),(51,56,"Categorical Dimension")]}),
("I would like to see my salary for different Mode ",{"entities":[(23,29,"Measure"),(44,48,"Categorical Dimension")]}),
("I would like to see my number of employees for different Method ",{"entities":[(23,42,"Measure"),(57,63,"Categorical Dimension")]}),
("I would like to see my dividend rate for different Channel ",{"entities":[(23,36,"Measure"),(51,58,"Categorical Dimension")]}),
("I would like to see my dividend for different Item ",{"entities":[(23,31,"Measure"),(46,50,"Categorical Dimension")]}),
("I would like to see my D/E Ratio for different Department ",{"entities":[(23,32,"Measure"),(47,57,"Categorical Dimension")]}),
("I would like to see my CAPEX for different order type ",{"entities":[(23,28,"Measure"),(43,53,"Categorical Dimension")]}),
("I would like to see my OPEX for different Section ",{"entities":[(23,27,"Measure"),(42,49,"Categorical Dimension")]}),
("I would like to see my Turnover for different Division ",{"entities":[(23,31,"Measure"),(46,54,"Categorical Dimension")]}),
("I would like to see my Working Capital for different Brand ",{"entities":[(23,38,"Measure"),(53,58,"Categorical Dimension")]}),
("I would like to see my Burn rate for different Category ",{"entities":[(23,32,"Measure"),(47,55,"Categorical Dimension")]}),
("I would like to see my OCF for different Lines ",{"entities":[(23,26,"Measure"),(41,46,"Categorical Dimension")]}),
("I would like to see my Operating Cash Flow for different Store ",{"entities":[(23,42,"Measure"),(57,62,"Categorical Dimension")]}),
("I would like to see my EBIT% for different store name ",{"entities":[(23,28,"Measure"),(43,53,"Categorical Dimension")]}),
("I would like to see my EBITDA% for different Zones ",{"entities":[(23,30,"Measure"),(45,50,"Categorical Dimension")]}),
("I would like to see my Operating Profit% for different Block ",{"entities":[(23,40,"Measure"),(55,60,"Categorical Dimension")]}),
("I would like to see my GM% for different Region ",{"entities":[(23,26,"Measure"),(41,47,"Categorical Dimension")]}),
("I would like to see my Gross Margin% for different State ",{"entities":[(23,36,"Measure"),(51,56,"Categorical Dimension")]}),
("I would like to see my Profit Margin% for different City ",{"entities":[(23,37,"Measure"),(52,56,"Categorical Dimension")]}),
("I would like to see my Profit% for different Country ",{"entities":[(23,30,"Measure"),(45,52,"Categorical Dimension")]}),
("I would like to see my Profit for different Location ",{"entities":[(23,29,"Measure"),(44,52,"Categorical Dimension")]}),
("I would like to see my Loss% for different length of service slabs ",{"entities":[(23,28,"Measure"),(43,66,"Categorical Dimension")]}),
("I would like to see my Loss for different employee performance ",{"entities":[(23,27,"Measure"),(42,62,"Categorical Dimension")]}),
("I would like to see my Tax for different source ",{"entities":[(23,26,"Measure"),(41,47,"Categorical Dimension")]}),
("I would like to see my Interest rate for different business unit ",{"entities":[(23,36,"Measure"),(51,64,"Categorical Dimension")]}),
("I would like to see my Exceptionals for different zone ",{"entities":[(23,35,"Measure"),(50,54,"Categorical Dimension")]}),
("I would like to see my Monitoring costs for different gender ",{"entities":[(23,39,"Measure"),(54,60,"Categorical Dimension")]}),
("I would like to see my Direct Cost for different years of service ",{"entities":[(23,34,"Measure"),(49,65,"Categorical Dimension")]}),
("I would like to see my Depreciation for different position ",{"entities":[(23,35,"Measure"),(40,58,"Categorical Dimension")]}),
("I would like to see my Other income for different department ",{"entities":[(23,35,"Measure"),(50,60,"Categorical Dimension")]}),
("I would like to see my EBIT for different hierarchy ",{"entities":[(23,27,"Measure"),(42,51,"Categorical Dimension")]}),
("I would like to see my Operating Income for different location ",{"entities":[(23,39,"Measure"),(54,62,"Categorical Dimension")]}),
("I would like to see my Operating Profit for different division ",{"entities":[(23,39,"Measure"),(54,62,"Categorical Dimension")]}),
("I would like to see my Cost of Sales for different service group ",{"entities":[(23,36,"Measure"),(51,64,"Categorical Dimension")]}),
("I would like to see my vacation days for different age group ",{"entities":[(23,36,"Measure"),(51,60,"Categorical Dimension")]}),
("I would like to see my leavers for different levels ",{"entities":[(23,30,"Measure"),(45,51,"Categorical Dimension")]}),
("I would like to see my work tenure for different grade ",{"entities":[(23,34,"Measure"),(49,54,"Categorical Dimension")]}),
("I would like to see my Staff training cost for different accounting_flag ",{"entities":[(23,42,"Measure"),(57,72,"Categorical Dimension")]}),
("I would like to see my length of service for different accounting_flag ",{"entities":[(23,40,"Measure"),(55,70,"Categorical Dimension")]}),
("I would like to see my commission for different off_region ",{"entities":[(23,33,"Measure"),(38,58,"Categorical Dimension")]}),
("I would like to see my workplace injuries for different fund_type_ind ",{"entities":[(23,41,"Measure"),(56,69,"Categorical Dimension")]}),
("I would like to see my referral count for different StoreResults ",{"entities":[(23,37,"Measure"),(52,64,"Categorical Dimension")]}),
("I would like to see my number of referrals for different pending ",{"entities":[(23,42,"Measure"),(57,64,"Categorical Dimension")]}),
("I would like to see my claims payment for different new_items ",{"entities":[(23,37,"Measure"),(52,61,"Categorical Dimension")]}),
("I would like to see my commission payment for different Claim severity ",{"entities":[(23,41,"Measure"),(56,70,"Categorical Dimension")]}),
("I would like to see my overtime payment for different Product Name ",{"entities":[(23,39,"Measure"),(54,66,"Categorical Dimension")]}),
("I would like to see my churn rate for different Product type ",{"entities":[(23,33,"Measure"),(48,60,"Categorical Dimension")]}),
("I would like to see my employee turnover for different Product category ",{"entities":[(23,40,"Measure"),(55,71,"Categorical Dimension")]}),
("I would like to see my overtime for different Claim status ",{"entities":[(23,31,"Measure"),(46,58,"Categorical Dimension")]}),
("I would like to see my referral incentive for different Claim type ",{"entities":[(23,41,"Measure"),(56,66,"Categorical Dimension")]}),
("I would like to see my LOP for different Basis ",{"entities":[(23,26,"Measure"),(41,46,"Categorical Dimension")]}),
("Show me the total revenue for 5 years ",{"entities":[(12,25,"Measure"),(30,37,"Timeline")]}),
("Show me GM for last 10 months across all verticals ",{"entities":[(8,10,"Measure"),(20,29,"Timeline"),(41,50,"Categorical Dimension")]}),
("Show me my expense incurred over the last 5 years ",{"entities":[(11,18,"Measure"),(37,49,"Timeline")]}),
("Count of employees having length of service more than 10 years ",{"entities":[(26,43,"Measure"),(54,62,"Timeline")]}),
("Show how my OCF are varying with different interest rates ",{"entities":[(12,15,"Measure"),(43,57,"Measure")]}),
("What was the turnover for last 2 years ",{"entities":[(13,21,"Measure"),(31,38,"Timeline")]}),
("Highlight the months with the Profit Margin less than 40% ",{"entities":[(15,21,"Timeline"),(31,44,"Measure")]}),
("Show me the months where the revenue is greater than or equal to the revenue target ",{"entities":[(13,19,"Timeline"),(29,37,"Measure"),(70,84,"Goal Measure")]}),
("Plot my GM for 5 verticals for the last 2 years ",{"entities":[(8,10,"Measure"),(17,26,"Categorical Dimension"),(40,47,"Timeline")]}),
("I want to see Revenue vs Expense for the last 5 years ",{"entities":[(14,21,"Measure"),(25,32,"Measure"),(46,53,"Timeline")]}),
("I would like to see my Loss of Pay for different Policy Ref ",{"entities":[(23,34,"Measure"),(49,59,"Categorical Dimension")]}),
("I would like to see my FTE count for different Insd ",{"entities":[(23,32,"Measure"),(47,51,"Categorical Dimension")]}),
("I would like to see my FTE vacancy count for different Risk Code Pol ",{"entities":[(23,40,"Measure"),(55,68,"Categorical Dimension")]}),
("I would like to see my vacancy count for different Group Risk Code ",{"entities":[(23,36,"Measure"),(51,66,"Categorical Dimension")]}),
("I would like to see my vacancy for different BPC Code ",{"entities":[(23,30,"Measure"),(45,53,"Categorical Dimension")]}),
("I would like to see my filled vacancies for different Division ",{"entities":[(23,39,"Measure"),(54,62,"Categorical Dimension")]}),
("I would like to see my open vacancies for different Office ",{"entities":[(23,37,"Measure"),(52,58,"Categorical Dimension")]}),
("I would like to see my joining bonus for different Vertical ",{"entities":[(23,36,"Measure"),(51,59,"Categorical Dimension")]}),
("I would like to see my notice period for different department ",{"entities":[(23,36,"Measure"),(51,61,"Categorical Dimension")]}),
("I would like to see my relocation charges for different service line ",{"entities":[(23,41,"Measure"),(56,68,"Categorical Dimension")]}),
("I would like to see my number of requisitions for different Horizontal ",{"entities":[(23,45,"Measure"),(60,70,"Categorical Dimension")]}),
("I would like to see my number of resignations for different Vertical ",{"entities":[(23,45,"Measure"),(60,68,"Categorical Dimension")]}),
("I would like to see my number of promotions for different Geography ",{"entities":[(23,43,"Measure"),(58,67,"Categorical Dimension")]}),
("I would like to see my number of enrollments for different Sub-business group ",{"entities":[(23,44,"Measure"),(59,77,"Categorical Dimension")]}),
("I would like to see my workforce tenure for different Business Group ",{"entities":[(23,39,"Measure"),(54,68,"Categorical Dimension")]}),
("I would like to see my workforce for different Stream ",{"entities":[(23,32,"Measure"),(47,53,"Categorical Dimension")]}),
("I would like to see my headcount for different Revenue Type ",{"entities":[(23,32,"Measure"),(47,59,"Categorical Dimension")]}),
("I would like to see my Expected YTD for different broker ",{"entities":[(24,36,"Goal Measure"),(50,56,"Categorical Dimension")]}),
("I would like to see my Quoted EPI for different lloyd's broker ",{"entities":[(23,33,"Goal Measure"),(48,62,"Categorical Dimension")]}),
("I would like to see my Forecast Premium for different event ",{"entities":[(23,39,"Goal Measure"),(54,59,"Categorical Dimension")]}),
("I would like to see my Forecast Premium for different accounting classes ",{"entities":[(23,39,"Goal Measure"),(54,72,"Categorical Dimension")]}),
("I would like to see my Revenue Target for different Claim severity ",{"entities":[(23,37,"Goal Measure"),(52,66,"Categorical Dimension")]}),
("I would like to see my Overheads Budget for different policy holder ",{"entities":[(23,39,"Goal Measure"),(54,67,"Categorical Dimension")]}),
("I would like to see my EBITDA Budget for different policy type ",{"entities":[(23,36,"Goal Measure"),(51,62,"Categorical Dimension")]}),
("I would like to see my Revenue Budget for different policy ",{"entities":[(23,37,"Goal Measure"),(52,58,"Categorical Dimension")]}),
("I would like to see my target headcount for different Product Name ",{"entities":[(23,39,"Goal Measure"),(54,66,"Categorical Dimension")]}),
("I would like to see my completed_mtd for different Product class ",{"entities":[(23,36,"Measure"),(51,64,"Categorical Dimension")]}),
("I would like to see my completed_items for different Product type ",{"entities":[(23,38,"Measure"),(53,65,"Categorical Dimension")]}),
("I would like to see my AUM for different Product category ",{"entities":[(23,26,"Measure"),(41,57,"Categorical Dimension")]}),
("I would like to see my AsOf_sales for different Carrier ",{"entities":[(23,33,"Measure"),(48,55,"Categorical Dimension")]}),
("I would like to see my net_ytd for different managing agent ",{"entities":[(23,30,"Measure"),(45,59,"Categorical Dimension")]}),
("I would like to see my net_today for different agent ",{"entities":[(23,32,"Measure"),(47,52,"Categorical Dimension")]}),
("I would like to see my Net_Sales for different Claim status ",{"entities":[(23,32,"Measure"),(47,59,"Categorical Dimension")]}),
("I would like to see my net_mtd for different Claim type ",{"entities":[(23,30,"Measure"),(45,55,"Categorical Dimension")]}),
("I would like to see my Net_AFB for different Age group ",{"entities":[(23,30,"Measure"),(45,54,"Categorical Dimension")]}),
("I would like to see my MTDNetSales for different Group ",{"entities":[(23,34,"Measure"),(49,54,"Categorical Dimension")]}),
("I would like to see my mtd_sales_afb for different cohort ",{"entities":[(23,36,"Measure"),(51,57,"Categorical Dimension")]}),
("I would like to see my mtd_sales for different Order status ",{"entities":[(23,32,"Measure"),(47,59,"Categorical Dimension")]}),
("I would like to see my mtd_redem_afb for different Status ",{"entities":[(23,36,"Measure"),(51,57,"Categorical Dimension")]}),
("I would like to see my mtd_redem for different Size ",{"entities":[(23,32,"Measure"),(47,51,"Categorical Dimension")]}),
("I would like to see my mtd_percent for different Type ",{"entities":[(23,34,"Measure"),(49,53,"Categorical Dimension")]}),
("I would like to see my mtd_net_flow for different Quality ",{"entities":[(23,35,"Measure"),(50,57,"Categorical Dimension")]}),
("I would like to see my mtd_net for different Grade ",{"entities":[(23,30,"Measure"),(45,50,"Categorical Dimension")]}),
("I would like to see my MTD% for different Class ",{"entities":[(23,27,"Measure"),(42,47,"Categorical Dimension")]}),
("I would like to see my mtd for different Mode ",{"entities":[(23,26,"Measure"),(41,45,"Categorical Dimension")]}),
("I would like to see my YTDNetSales for different Method ",{"entities":[(23,34,"Measure"),(49,55,"Categorical Dimension")]}),
("I would like to see my ytd_sales_afb for different Channel ",{"entities":[(23,36,"Measure"),(51,58,"Categorical Dimension")]}),
("I would like to see my ytd_sales for different Item ",{"entities":[(23,32,"Measure"),(47,51,"Categorical Dimension")]}),
("I would like to see my ytd_redem_afb for different Department ",{"entities":[(23,36,"Measure"),(51,61,"Categorical Dimension")]}),
("I would like to see my ytd_redem for different order type ",{"entities":[(23,32,"Measure"),(47,57,"Categorical Dimension")]}),
("I would like to see my ytd_percent for different Section ",{"entities":[(23,34,"Measure"),(49,56,"Categorical Dimension")]}),
("I would like to see my ytd_net_flow for different Division ",{"entities":[(23,35,"Measure"),(50,58,"Categorical Dimension")]}),
("I would like to see my ytd_net for different Brand ",{"entities":[(23,30,"Measure"),(45,50,"Categorical Dimension")]}),
("I would like to see my YTD% for different Category ",{"entities":[(23,27,"Measure"),(42,50,"Categorical Dimension")]}),
("I would like to see my ytd for different Lines ",{"entities":[(23,26,"Measure"),(41,46,"Categorical Dimension")]}),
("I would like to see my usd_amt for different Store ",{"entities":[(23,30,"Measure"),(45,50,"Categorical Dimension")]}),
("I would like to see my total_sales_afb for different store name ",{"entities":[(23,38,"Measure"),(53,63,"Categorical Dimension")]}),
("I would like to see my total_sales for different Zones ",{"entities":[(23,34,"Measure"),(49,54,"Categorical Dimension")]}),
("I would like to see my total_redem_afb for different Block ",{"entities":[(23,38,"Measure"),(53,58,"Categorical Dimension")]}),
("I would like to see my total_redem for different Region ",{"entities":[(23,34,"Measure"),(49,55,"Categorical Dimension")]}),
("I would like to see my total_pending for different State ",{"entities":[(23,36,"Measure"),(51,56,"Categorical Dimension")]}),
("I would like to see my today_sales_afb for different City ",{"entities":[(23,38,"Measure"),(53,57,"Categorical Dimension")]}),
("I would like to see my today_sales for different Country ",{"entities":[(23,34,"Measure"),(49,56,"Categorical Dimension")]}),
("I would like to see my today_redem_afb for different Location ",{"entities":[(23,38,"Measure"),(53,61,"Categorical Dimension")]}),
("I would like to see my today_redem for different length of service slabs ",{"entities":[(23,34,"Measure"),(49,72,"Categorical Dimension")]}),
("I would like to see my today_net_flow for different employee performance ",{"entities":[(23,37,"Measure"),(52,72,"Categorical Dimension")]}),
("I would like to see my today_net for different source ",{"entities":[(23,32,"Measure"),(47,53,"Categorical Dimension")]}),
("I would like to see my today for different business unit ",{"entities":[(23,28,"Measure"),(43,56,"Categorical Dimension")]}),
("I would like to see my sales_afb for different zone ",{"entities":[(23,32,"Measure"),(47,51,"Categorical Dimension")]}),
("I would like to see my sales for different gender ",{"entities":[(23,28,"Measure"),(43,49,"Categorical Dimension")]}),
("I would like to see my redemptions_afb for different years of service ",{"entities":[(23,38,"Measure"),(53,69,"Categorical Dimension")]}),
("I would like to see my redemptions for different position ",{"entities":[(23,34,"Measure"),(49,57,"Categorical Dimension")]}),
("I would like to see my QTDNetSales for different department ",{"entities":[(23,34,"Measure"),(49,59,"Categorical Dimension")]}),
("I would like to see my qtd_sales for different hierarchy ",{"entities":[(23,32,"Measure"),(47,56,"Categorical Dimension")]}),
("I would like to see my qtd_redem for different location ",{"entities":[(23,32,"Measure"),(47,55,"Categorical Dimension")]}),
("I would like to see my pyr_redem for different division ",{"entities":[(23,32,"Measure"),(47,55,"Categorical Dimension")]}),
("I would like to see my pyr_net for different service group ",{"entities":[(23,30,"Measure"),(45,58,"Categorical Dimension")]}),
("I would like to see my avg policy size for different age group ",{"entities":[(23,38,"Measure"),(53,62,"Categorical Dimension")]}),
("I would like to see my underwriting speed for different levels ",{"entities":[(23,41,"Measure"),(56,62,"Categorical Dimension")]}),
("I would like to see my cost per claim for different grade ",{"entities":[(23,37,"Measure"),(52,57,"Categorical Dimension")]}),
("I would like to see my number of referrals for different accounting_flag ",{"entities":[(23,42,"Measure"),(57,72,"Categorical Dimension")]}),
("I would like to see my Premium for different accounting_flag ",{"entities":[(23,30,"Measure"),(45,60,"Categorical Dimension")]}),
("I would like to see my Payout for different off_region ",{"entities":[(23,29,"Measure"),(44,54,"Categorical Dimension")]}),
("I would like to see my Submitted EPI for different fund_type_ind ",{"entities":[(23,36,"Measure"),(51,64,"Categorical Dimension")]}),
("I would like to see my Actual EPI YTD for different StoreResults ",{"entities":[(23,37,"Measure"),(52,64,"Categorical Dimension")]}),
("I would like to see my time to settle a claim for different pending ",{"entities":[(23,45,"Measure"),(60,67,"Categorical Dimension")]}),
("I would like to see my Budget Premium for different new_items ",{"entities":[(23,37,"Measure"),(52,61,"Categorical Dimension")]}),
("I would like to see my PY Actual YTD for different Claim severity ",{"entities":[(23,36,"Measure"),(51,65,"Categorical Dimension")]}),
("I would like to see my Policy Count for different Product Name ",{"entities":[(23,35,"Measure"),(50,62,"Categorical Dimension")]}),
("I would like to see my Limit Remaining for different Product type ",{"entities":[(23,38,"Measure"),(53,65,"Categorical Dimension")]}),
("I would like to see my Plan Remaining for different Product category ",{"entities":[(23,37,"Measure"),(52,68,"Categorical Dimension")]}),
("I would like to see my Plan Remaining % for different Claim status ",{"entities":[(23,39,"Measure"),(54,66,"Categorical Dimension")]}),
("I would like to see my Claim Movement for different Claim type ",{"entities":[(23,37,"Measure"),(52,62,"Categorical Dimension")]}),
("I would like to see my Expiring EPI for different Basis ",{"entities":[(23,35,"Measure"),(50,55,"Categorical Dimension")]}),
("I would like to see my Lost / Lapsed EPI for different Policy Ref ",{"entities":[(23,40,"Measure"),(55,65,"Categorical Dimension")]}),
("I would like to see my Lapsed EPI for different Insd ",{"entities":[(23,33,"Measure"),(48,52,"Categorical Dimension")]}),
("I would like to see my Declinature & NTU EPI for different Risk Code Pol ",{"entities":[(23,44,"Measure"),(59,72,"Categorical Dimension")]}),
("I would like to see my Bound Premium for different Group Risk Code ",{"entities":[(23,36,"Measure"),(51,66,"Categorical Dimension")]}),
("I would like to see my Var % YoY for different BPC Code ",{"entities":[(23,32,"Measure"),(47,55,"Categorical Dimension")]}),
("I would like to see my Var Plan Used % for different Division ",{"entities":[(23,38,"Measure"),(53,61,"Categorical Dimension")]}),
("I would like to see my Benchmark Adequacy for different Office ",{"entities":[(23,41,"Measure"),(56,62,"Categorical Dimension")]}),
("I would like to see my Tech Adequacy for different Vertical ",{"entities":[(23,36,"Measure"),(51,59,"Categorical Dimension")]}),
("I would like to see my Attrition / Attr GILR for different department ",{"entities":[(23,44,"Measure"),(59,69,"Categorical Dimension")]}),
("I would like to see my Loss Ratio / GILR for different service line ",{"entities":[(23,40,"Measure"),(55,67,"Categorical Dimension")]}),
("I would like to see my Yet to Renew for different Horizontal ",{"entities":[(23,35,"Measure"),(50,60,"Categorical Dimension")]}),
("I would like to see my Actual YTD for different Geography ",{"entities":[(24,34,"Measure"),(48,57,"Categorical Dimension")]}),
("I would like to see my Variance to Prior Year for different Business Group ",{"entities":[(24,46,"Measure"),(60,74,"Categorical Dimension")]}),
("I would like to see my Renewal % for different Stream ",{"entities":[(23,32,"Measure"),(47,53,"Categorical Dimension")]}),
("I would like to see my New % for different Revenue Type ",{"entities":[(23,28,"Measure"),(43,55,"Categorical Dimension")]}),
("I would like to see my Rate Chg % for different portfolio ",{"entities":[(23,33,"Measure"),(48,57,"Categorical Dimension")]}),
("I would like to see my Retention % for different client ",{"entities":[(23,34,"Measure"),(49,55,"Categorical Dimension")]}),
("I would like to see my Bound Premium for different risk group ",{"entities":[(23,36,"Measure"),(51,61,"Categorical Dimension")]}),
("I would like to see my Overheads for different broker ",{"entities":[(23,32,"Measure"),(47,53,"Categorical Dimension")]}),
("I would like to see my EBITDA for different lloyd's broker ",{"entities":[(23,29,"Measure"),(44,58,"Categorical Dimension")]}),
("I would like to see my Revenue per day for different event ",{"entities":[(23,38,"Measure"),(53,58,"Categorical Dimension")]}),
("I would like to see my Net Profit Margin for different accounting classes ",{"entities":[(23,40,"Measure"),(55,73,"Categorical Dimension")]}),
("I would like to see my GM for different Claim severity ",{"entities":[(23,25,"Measure"),(40,54,"Categorical Dimension")]}),
("I would like to see my Gross Margin for different policy holder ",{"entities":[(23,35,"Measure"),(50,63,"Categorical Dimension")]}),
("I would like to see my Expense for different policy type ",{"entities":[(23,30,"Measure"),(45,56,"Categorical Dimension")]}),
("I would like to see my Revenue for different policy ",{"entities":[(23,30,"Measure"),(45,51,"Categorical Dimension")]}),
("I would like to see my Growth% for different Product Name ",{"entities":[(23,30,"Measure"),(45,57,"Categorical Dimension")]}),
("I would like to see my attrition rate for different Product class ",{"entities":[(23,37,"Measure"),(52,65,"Categorical Dimension")]}),
("I would like to see my Prior Yr YTD for different Vertical ",{"entities":[(23,36,"Measure"),(50,58,"Categorical Dimension")]}),
("I would like to see my Prior Yr YOY for different Sub-business group ",{"entities":[(23,35,"Measure"),(50,68,"Categorical Dimension")]}),
("Show me the total revenue for 5 years ",{"entities":[(12,25,"Measure"),(30,37,"Timeline")]}),
("Show me GM for last 10 months across all verticals ",{"entities":[(8,10,"Measure"),(20,29,"Timeline"),(41,50,"Categorical Dimension")]}),
("Show me my expense incurred over the last 5 years ",{"entities":[(11,18,"Measure"),(37,49,"Timeline")]}),
("Count of employees having length of service more than 10 years ",{"entities":[(26,43,"Measure"),(54,62,"Timeline")]}),
("Show how my OCF are varying with different interest rates ",{"entities":[(12,15,"Measure"),(43,57,"Measure")]}),
("What was the turnover for last 2 years ",{"entities":[(13,21,"Measure"),(31,38,"Timeline")]}),
("Highlight the months with the Profit Margin less than 40% ",{"entities":[(15,21,"Timeline"),(31,44,"Measure")]}),
("Show me the months where the revenue is greater than or equal to the revenue target ",{"entities":[(13,19,"Timeline"),(29,37,"Measure"),(70,84,"Goal Measure")]}),
("Plot my GM for 5 verticals for the last 2 years ",{"entities":[(8,10,"Measure"),(17,26,"Categorical Dimension"),(40,47,"Timeline")]}),
("I want to see Revenue vs Expense for the last 5 years ",{"entities":[(14,21,"Measure"),(25,32,"Measure"),(46,53,"Timeline")]}),
("Plot my GM for 5 verticals for the last 9 years ",{"entities":[(8,10,"Measure"),(17,26,"Categorical Dimension"),(40,47,"Timeline")]}),
("I want to see Revenue vs Expense for the last 10 years ",{"entities":[(14,21,"Measure"),(25,32,"Measure"),(46,54,"Timeline")]}), 
("I would like to see my Expense for different policy type ",{"entities":[(23,30,"Measure"),(45,56,"Categorical Dimension")]}),
("I would like to see my Revenue for different policy ",{"entities":[(23,30,"Measure"),(45,51,"Categorical Dimension")]}),
("Plot my commission payment against my Claim severity ",{"entities":[(8,26,"Measure"),(38,52,"Categorical Dimension")]}),
("Plot my overtime payment against my Product Name ",{"entities":[(8,24,"Measure"),(36,48,"Categorical Dimension")]}),
("Plot my churn rate against my Product type ",{"entities":[(8,18,"Measure"),(30,42,"Categorical Dimension")]}),
("Show me Revenue per day for all event ",{"entities":[(8,23,"Measure"),(32,37,"Categorical Dimension")]}),
("Show me Net Profit Margin for all accounting classes ",{"entities":[(8,25,"Measure"),(34,52,"Categorical Dimension")]}),
("Show me GM for all Claim severity ",{"entities":[(8,10,"Measure"),(19,33,"Categorical Dimension")]}),
("Show me Gross Margin for all policy holder ",{"entities":[(8,20,"Measure"),(29,42,"Categorical Dimension")]}),
("Show me Expense for all policy type ",{"entities":[(8,15,"Measure"),(24,35,"Categorical Dimension")]}),
("what is my EBIT% across different store name ",{"entities":[(11,16,"Measure"),(34,44,"Categorical Dimension")]}),
("what is my EBITDA% across different Zones ",{"entities":[(11,18,"Measure"),(36,41,"Categorical Dimension")]}),
("what is my Operating Profit% across different Block ",{"entities":[(11,28,"Measure"),(46,51,"Categorical Dimension")]}),
("what is my GM% across different Region ",{"entities":[(11,14,"Measure"),(32,38,"Categorical Dimension")]}),
("what is my Gross Margin% across different State ",{"entities":[(11,24,"Measure"),(42,47,"Categorical Dimension")]}),
("what is my Profit Margin% across different City ",{"entities":[(11,25,"Measure"),(43,47,"Categorical Dimension")]}),
("what is my Profit% across different Country ",{"entities":[(11,18,"Measure"),(36,43,"Categorical Dimension")]}),
("what is my Profit across different Location ",{"entities":[(11,17,"Measure"),(35,43,"Categorical Dimension")]}),
("what is my Loss% across different length of service slabs ",{"entities":[(11,16,"Measure"),(34,57,"Categorical Dimension")]}),
("Please plot GM% vs Region ",{"entities":[(12,15,"Measure"),(19,25,"Categorical Dimension")]}),
("Please plot Gross Margin% vs State ",{"entities":[(12,25,"Measure"),(29,34,"Categorical Dimension")]}),
("Please plot Profit Margin% vs City ",{"entities":[(12,26,"Measure"),(30,34,"Categorical Dimension")]}),
("Please plot Profit% vs Country ",{"entities":[(12,19,"Measure"),(23,30,"Categorical Dimension")]}),
("Please plot Profit vs Location ",{"entities":[(12,18,"Measure"),(22,30,"Categorical Dimension")]}),
("Please plot Loss% vs length of service slabs ",{"entities":[(12,17,"Measure"),(21,44,"Categorical Dimension")]}),
("length of service vs accounting_flag ",{"entities":[(0,17,"Measure"),(21,36,"Categorical Dimension")]}),
("commission vs off_region ",{"entities":[(0,10,"Measure"),(14,24,"Categorical Dimension")]}),
("workplace injuries vs fund_type_ind ",{"entities":[(0,18,"Measure"),(22,35,"Categorical Dimension")]}),
("referral count vs StoreResults ",{"entities":[(0,14,"Measure"),(18,30,"Categorical Dimension")]}),
("number of referrals vs pending ",{"entities":[(0,19,"Measure"),(23,30,"Categorical Dimension")]}),
("claims payment vs new_items ",{"entities":[(0,14,"Measure"),(18,27,"Categorical Dimension")]}),
("commission payment vs Claim severity ",{"entities":[(0,18,"Measure"),(22,36,"Categorical Dimension")]}),
("overtime payment vs Product Name ",{"entities":[(0,16,"Measure"),(20,32,"Categorical Dimension")]}),
("churn rate vs Product type ",{"entities":[(0,10,"Measure"),(14,26,"Categorical Dimension")]}),
("employee turnover vs Product category ",{"entities":[(0,17,"Measure"),(21,37,"Categorical Dimension")]})]

# %%
for sent in TRAIN_DATA:
    sent.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-1c087aa3c350> in <module>
#       1 for sent in TRAIN_DATA:
# ----> 2     sent.strip()
#       3
#
# AttributeError: 'tuple' object has no attribute 'strip'

# %%
for i in tqdm(TRAIN_DATA):
	try:
		text,annot = i
	except:
		print(i[0])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 1563/1563 [00:00<00:00, 783424.61it/s]

# %%
for text,annot  in tqdm(TRAIN_DATA): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    for start, end, label in annot["entities"]: # add character indexes
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents # label the text with the ents
    db.add(doc)

db.to_disk("D:\\SpacyNER\\train.spacy") # save the docbin object
# Out:
# ...
#  17%|█████████████▎                                                               | 270/1563 [00:00<00:00, 1354.21it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# ...
#  37%|████████████████████████████▍                                                | 577/1563 [00:00<00:00, 1463.97it/s]
# Skipping entity
# Skipping entity
# ...
#  77%|██████████████████████████████████████████████████████████▏                 | 1196/1563 [00:00<00:00, 1510.58it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 1563/1563 [00:01<00:00, 1445.74it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity

# %%
#testing
import spacy
import json
nlp=spacy.load("D:\\SpacyNER\\output\\model-best")
doc=nlp("Show me revenue vs vertical")
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\spacy\util.py:693: UserWarning: [W095] Model 'en_pipeline' (0.0.0) requires spaCy >=3.0.6,<3.1.0 and is incompatible with the current version (3.0.0rc5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# RegistryError                             Traceback (most recent call last)
# <ipython-input-119-df8826ea2dff> in <module>
#       2 import spacy
#       3 import json
# ----> 4 nlp=spacy.load("D:\\SpacyNER\\output\\model-best")
#       5 doc=nlp("Show me revenue vs vertical")
#       6 for ent in doc.ents:
#
# ~\anaconda3\lib\site-packages\spacy\__init__.py in load(name, disable, exclude, config)
# ...

# %%
#convert to json
import json
with open('train.json', 'w') as f:
    json.dump(TRAIN_DATA, f)

# %%
#convert to pickle
import pickle
import os
os.chdir('D:\\SpacyNER')

filename="train_pickle.txt"
file=open(filename,'wb')
pickle.dump(TRAIN_DATA,file)

file=open('train_pickle.txt','rb')
TRAIN_DATA=pickle.load(file)
TRAIN_DATA[0]
# Out:
# ('Show me Rate Chg % for all portfolio',
#  {'entities': [(9, 19, 'Measure'), (27, 36, 'Categorical Dimension')]})
